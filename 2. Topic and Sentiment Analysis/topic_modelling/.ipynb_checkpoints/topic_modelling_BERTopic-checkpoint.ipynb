# %% [markdown]
# # Topic modelling - BERTopic
#
# This file creates topics for the dataset containing "Skriflig fråga" (questions) and "svar på skriftlig fråga" (answers) fetched from riksdagen.se. This is done by using a model called BERTopic [1]. First the techinque is tested on a smaller dataset containing only data from 2018 to 2022 and is then applied to all dat fetched from 2006 to 2022. This file creates BERTopic models on this data. The models that was created from this file have been saved to a folder called "models" and can be easialy loaded (how to load them in can be seen in the code), so that we can have consistent topics and don't have to run this code each time. Note that the models for the data 2018 to 2022 is not included since this was only to test out BERTopic and I didn't want to include even more data then I already have.
#
# File made by: Elsa Kidman
#
# [1] M. Grootendorst, BERTopic: Neural topic modeling with a class-based TF-IDF procedure, 2022. https://maartengr.github.io/BERTopic/index.html

# %% [markdown]
# ## How to run
# To be able to run the following code the following python packages are required:
# - tensorflow needs to be updated
# - BERTopic
# - sklearn
# - pickle
# - nltk
# - numpy

# %%
# To be able to run this file the following packages needs to be installed
# !pip3 install --upgrade tensorflow
# !pip3 install BERTopic

# %%
import pickle
import json
import numpy as np
from bertopic import BERTopic
from sklearn.feature_extraction.text import CountVectorizer
import nltk
from nltk.corpus import stopwords

# Download NLTK stopwords data
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# ## BERTopic
# It exist different ways to find the topics of the questions and answers*. I'm going to get the topics of the following:
# - Get topics for a combined entry, i.e. questions and answers combined.
# - Get topics for answers and questions seperatly. However, execute the BERTopic model with both questions and answers so that they get the same set of topics.
# - One could also try to get topics for answers and questions seperatly by fit and transform the data for questions and answers seperate. However, then they will get completely different set of topics and therefore I think this is not a good solution for us.
#
#
# Note:
# - The text does not need to be preprocessed (tokenisation, stemming, stopword removale etc.) before applying BERTopic [2].
# - Outlier topics need to handled. These are topics of nr -1 [3].
# - BERTopic automatically chooses the number of topics for us.
#
#
# \* Questions refers to "skriftlig fråga" and answers refers to "svar på skriftlig fråga"
#
# [2] M. Grootendorst, Frequently Asked Questions, 2023,
# https://maartengr.github.io/BERTopic/faq.html#should-i-preprocess-the-data
#
# [3] M. Grootendorst, Outlier reduction, 2023, https://maartengr.github.io/BERTopic/getting_started/outlier_reduction/outlier_reduction.html

# %%
# Reduces outlier topics. These are marked as the topic nr -1
def reduce_outliers(model, text, topics):

  # Reduce outliers
  new_topics = model.reduce_outliers(text, topics)
  # Update Topic Representation
  model.update_topics(text, topics=new_topics, vectorizer_model=vectorizer_model)
  return model

# Get list of Swedish stopwords and add some more
stopword_custom = stopwords.words('swedish')
stop_list = ["ska", "ske", "det", "vore"]
stopword_custom.extend(stop_list)
stop_words = set(stopword_custom)
stop_words = list(stop_words)

# define our CountVectorizer to remove stopwords
vectorizer_model = CountVectorizer(stop_words=stop_words)

# Improved model 2
vectorizer_model = CountVectorizer(min_df=2, stop_words = stop_words, ngram_range=(1, 2))

# %%
# Code to Save and load the models. Note: Change the path
# # Save model, topics and probabilities
# model.save("/models", serialization="pickle")

# with open("/models", "wb") as fp:
#   pickle.dump(topics, fp)

# with open("/models", "wb") as fp:
#   pickle.dump(probs, fp)

# # Load model, topics and probabilities
# model = BERTopic.load("/models")

# with open("/models", "rb") as fp:
#   topics = pickle.load(fp)

# with open("/models", "rb") as fp:
#   probs = pickle.load(fp)

# # Hot to save as json
# with open("/models", "w") as fp:
#     json.dump(result_dict, fp)

# %% [markdown]
# ## Dataset containing questions and answers from 2018 to 2022
#
# First I test BERTopic on the smaller dataset containing data from 2018 to 2022. This is only to test and learn BERTopicon a smaller dataset, scroll down to all data for the final product. Again, this model is not included in the models folder since it is only to learn.

# %%
# TODO: change path
f = open('../../data/data 2018-09-09 2022-09-11/data_FINAL_2018-09-09_to_2022-09-11.json')
data_init = json.load(f)

# %%
# Remove person names from question/answers.
# NOTE: This worked for the data 2018-2022, but not on all data since the questions format is different troughout the years (see data_exploration_all_years).
def remove_names(question):
    ## Remove the first two lines
    lines = question.split('\n')[2:]
    new_text = '\n'.join(lines)
    return new_text

# Generate lists of the different data needed
orginal_text_combined = []
orginal_questions = []
orginal_answers = []
original_qa = []

for entry in data_init:
    question = entry['question']
    answer = entry['answer']

    # remove the to/from formality from question
    question2 = remove_names(question)
    orginal_questions.append(question2)
    original_qa.append(question2)

    # Answers
    orginal_answers.append(answer)
    original_qa.append(answer)

    # Combined questions and answers
    orginal_text_combined.append(question2+answer)

print(f"Amount of datapoints: {len(orginal_text_combined)}")
# Out:
# Amount of datapoints: 6603

# %% [markdown]
# ### Preform BERTopic on questions and answers seperatly
# NOTE: We decided not to use this since questions and answers get different set of topics.

# %%
# Train the BERTopic model on the questions
model_questions = BERTopic(language="swedish",calculate_probabilities=True, vectorizer_model=vectorizer_model)
topics_questions, probs_questions = model_questions.fit_transform(orginal_questions)
model_questions_improved = reduce_outliers(model_questions, orginal_questions, topics_questions)

# Train the BERTopic model on the answers
model_answers = BERTopic(language="swedish",calculate_probabilities=True, vectorizer_model=vectorizer_model)
topics_answers, probs_answers = model_answers.fit_transform(orginal_answers)
model_answers_improved = reduce_outliers(model_answers, orginal_answers, topics_answers)

# %%
# # Save questions model, topic and probs. NOTE: these are not included in the models folder since it would take up to much space
# model_questions.save("models/model_questions_trained_seperately", serialization="pickle")

# with open("models/topics_questions_trained_seperately", "wb") as fp:
#   pickle.dump(topics_questions, fp)

# with open("models/probs_questions_trained_seperately", "wb") as fp:
#   pickle.dump(probs_questions, fp)

# # Save answers model, topic and probs
# model_answers.save("models/model_answers_trained_seperately", serialization="pickle")

# with open("models/topics_answers_trained_seperately", "wb") as fp:
#   pickle.dump(topics_answers, fp)

# with open("models/probs_answers_trained_seperately", "wb") as fp:
#   pickle.dump(probs_answers, fp)

# %%
model_questions.get_topic_info()
model_answers.get_topic_info()

# %%
# Get topics for each document (data entry) and save them the the data json file.
document_topic_questions = model_questions.get_document_info(orginal_questions)
document_topic_answers = model_answers.get_document_info(orginal_answers)
document_topic_combined = model_combined.get_document_info(orginal_text_combined)

columns_to_extract = ['Name', 'Top_n_words']
data = data_init.copy()

for i, entry in enumerate(data):
    # combined
    id_topic, words = document_topic_combined.loc[i, columns_to_extract].values
    words = words.split(' - ')
    words = ', '.join(words)
    print(words)
    break

    #questions
    id_topic_Q, wordsQ = document_topic_questions.loc[i, columns_to_extract].values
    words_Q = wordsQ.split(' - ')
    words_Q = ', '.join(words_Q)

    if len(entry['answer']) == 0:
        # Answers
        id_topic_A = ''
        words_A =  []

    else:
        # Answers
        nameA, wordsA = document_topic_answers.loc[i, columns_to_extract].values
        wordsA = wordsA.split(' - ')

    new_element = { 'id_topic_combined': id, 'top_10_words_combined': words,
                    'id_topic_question': id_topic_Q, 'top_n_words_question': words_Q,
                    'id_topic_answer': id_topic_A, 'top_n_words_answer': words_A}

    entry.update(new_element)

# %% [markdown]
# ### BERTopic on question and answers seperate but trained at the same time, so they get same set of topics
# Note: Here bertopic setting nr_topics='auto' was used to automatically let BERTopic reduce amount of topics. After consideration we decided not to use this since we got a large nonsense topic (topic 0). It was not used on the dataset with all data from 2006-2022.

# %%
model_qa = BERTopic(language="swedish",
                    calculate_probabilities=True,
                    vectorizer_model=vectorizer_model,
                    nr_topics = 'auto') # by using auto, BERTopic decreases topics

topics_qa, probs_qa = model_qa.fit_transform(original_qa)

model_qa.get_topic_info()

# %%
# model_qa = BERTopic.load("/content/gdrive/MyDrive/IT5/Data/model_qa")
# model_qa.get_topic_info()

# %%
model_qa = reduce_outliers(model_qa, original_qa, topics_qa)
model_qa.get_topic_info()
# Out:
# 2023-11-28 10:05:01,808 - BERTopic - WARNING: Using a custom list of topic assignments may lead to errors if topic reduction techniques are used afterwards. Make sure that manually assigning topics is the last step in the pipeline.Note that topic embeddings will also be created through weightedc-TF-IDF embeddings instead of centroid embeddings.
#     Topic  Count                                               Name  \
# 0       0  10352                0_regeringen_fråga_sverige_åtgärder
# 1       1    433                      1_elever_skolan_lärare_skolor
# 2       2    138     2_besvaras_övergångsregering_skriftliga_frågor
# 3       3    144                 3_turkiet_turkiska_turkiets_syrien
# 4       4    127             4_israel_palestinska_palestina_israels
# 5       5     99               5_taiwan_taiwans_who_internationella
# 6       6    115               6_iran_iranska_mänskliga_rättigheter
# 7       7     90  7_etiopien_tigray_mänskliga_mänskliga rättigheter
# 8       8    112                     8_journalister_medier_radio_tv
# 9       9     79        9_kulturen_kultur_kultursektorn_kulturarvet
# 10     10     70   10_kristna_religions_religiösa_övertygelsefrihet
# 11     11     59   11_spel_spelmarknaden_shekarabi_spelinspektionen
# 12     12     61  12_idrott_idrotten_aktivitet_riksidrottsförbundet
# 13     13     62              13_venezuela_kuba_mänskliga_politiska
# 14     14     58             14_rasism_hatbrott_antisemitism_former
# 15     15     78  15_poliser_polismyndigheten_polisanställda_pol...
# 16     16     64                          16_kina_hongkong_kinas_eu
# 17     17     41          17_azerbajdzjan_armenien_nagorno_karabach
# 18     18     39           18_myanmar_militären_militärkuppen_sudan
# 19     19     45  19_konsumenter_angelica lundberg_lundberg_ange...
# 20     20     36            20_5g_pts_utbyggnaden_sveriges säkerhet
# 21     21     35                 21_snus_tobak_cigaretter_riksdagen
# 22     22     36               22_folkmordet_1915_folkmord_osmanska
# 23     23     36           23_postnord_post_brev_samhällsomfattande
# 24     24     45                      24_hongkong_hongkongs_kina_eu
# 25     25     27                                             25____
# 26     26     47            26_ukraina_flyktingar_ukrainska_sverige
# 27     27     23           27_solceller_privatpersoner_bygglov_kläm
# 28     28     22                     28_unrwa_palestinska_fn_unrwas
# 29     29     22  29_kamerabevakning_kameror_datainspektionen_ka...
# 30     30     33           30_morell_thomas morell_thomas_morell sd
# 31     31     34                       31_kina_os_mänskliga_bojkott
# 32     32     33                     32_fisket_östersjön_fiske_fisk
# 33     33     33  33_gravida_förlossningsvården_förlossning_kvinnor
# 34     34     27               34_xinjiang_kina_kinesiska_mänskliga
# 35     35     24            35_diabetes_fetma_övervikt_riktlinjerna
# 36     36     20  36_estland_nya uppgifterna_uppgifterna_estland...
# 37     37     21   37_krigsmateriel_export_isp_export krigsmateriel
# 38     38     31  38_studieförbunden_folkbildningsrådet_folkbild...
# 39     39     17                 39_ubåten_vraket_bärgning_aspekter
# 40     40     30  40_folkbokföringen_adress_skatteverket_folkbok...
# 41     41     17                     41_libanon_explosionen_fn_stöd
# 42     42     20          42_pass_väntetiderna_väntetider_nytt pass
# 43     43     18                 43_kinesiska_5g_huawei_utbyggnaden
# 44     44     16                44_nordkorea_usa_nordkoreas_luhansk
# 45     45     13  45_genomiska_nya genomiska_tekniker_genomiska ...
# 46     46     17          46_mali_militära_takuba_militära insatser
# 47     47     14        47_antibiotika_antibiotikaresistens_djur_eu
# 48     48     16                 48_hagia_hagia sofia_sofia_turkiet
# 49     49     22  49_domstolarna_försvarare_advokater_offentlig ...
# 50     50     32  50_hedersrelaterat_hedersrelaterat våld_våld f...
# 51     51     36                      51_testning_covid 19_covid_19
# 52     52     13  52_våldsmonopol_statens våldsmonopol_åtgärdspa...
# 53     53     21             53_flygplatser_flygplats_flyget_bromma
# 54     54     15  54_saudiarabien_mänskliga_rättigheter_mänsklig...
# 55     55     11                   55_film_tv_svensk_filminstitutet
# 56     56     27    56_tillväxtverket_korttidsarbete_företag_stödet
#
#                                        Representation  \
# 0   [regeringen, fråga, sverige, åtgärder, 2020, a...
# 1   [elever, skolan, lärare, skolor, ekström, anna...
# 2   [besvaras, övergångsregering, skriftliga, fråg...
# 3   [turkiet, turkiska, turkiets, syrien, mänsklig...
# 4   [israel, palestinska, palestina, israels, pale...
# 5   [taiwan, taiwans, who, internationella, intern...
# 6   [iran, iranska, mänskliga, rättigheter, mänskl...
# 7   [etiopien, tigray, mänskliga, mänskliga rättig...
# 8   [journalister, medier, radio, tv, oberoende, p...
# 9   [kulturen, kultur, kultursektorn, kulturarvet,...
# 10  [kristna, religions, religiösa, övertygelsefri...
# 11  [spel, spelmarknaden, shekarabi, spelinspektio...
# 12  [idrott, idrotten, aktivitet, riksidrottsförbu...
# 13  [venezuela, kuba, mänskliga, politiska, chile,...
# 14  [rasism, hatbrott, antisemitism, former, antis...
# 15  [poliser, polismyndigheten, polisanställda, po...
# 16  [kina, hongkong, kinas, eu, kinesiska, hongkon...
# 17  [azerbajdzjan, armenien, nagorno, karabach, na...
# 18  [myanmar, militären, militärkuppen, sudan, fn,...
# 19  [konsumenter, angelica lundberg, lundberg, ang...
# 20  [5g, pts, utbyggnaden, sveriges säkerhet, säke...
# 21  [snus, tobak, cigaretter, riksdagen, produkter...
# 22  [folkmordet, 1915, folkmord, osmanska, erkänna...
# 23  [postnord, post, brev, samhällsomfattande, pts...
# 24  [hongkong, hongkongs, kina, eu, kinas, säkerhe...
# 25                               [, , , , , , , , , ]
# 26  [ukraina, flyktingar, ukrainska, sverige, uppe...
# 27  [solceller, privatpersoner, bygglov, kläm, bet...
# 28  [unrwa, palestinska, fn, unrwas, läromedel, or...
# 29  [kamerabevakning, kameror, datainspektionen, k...
# 30  [morell, thomas morell, thomas, morell sd, mor...
# 31  [kina, os, mänskliga, bojkott, mänskliga rätti...
# 32  [fisket, östersjön, fiske, fisk, strömming, ku...
# 33  [gravida, förlossningsvården, förlossning, kvi...
# 34  [xinjiang, kina, kinesiska, mänskliga, eu, utv...
# 35  [diabetes, fetma, övervikt, riktlinjerna, nati...
# 36  [estland, nya uppgifterna, uppgifterna, estlan...
# 37  [krigsmateriel, export, isp, export krigsmater...
# 38  [studieförbunden, folkbildningsrådet, folkbild...
# 39  [ubåten, vraket, bärgning, aspekter, krigsmate...
# 40  [folkbokföringen, adress, skatteverket, folkbo...
# 41  [libanon, explosionen, fn, stöd, landet, liban...
# 42  [pass, väntetiderna, väntetider, nytt pass, ti...
# 43  [kinesiska, 5g, huawei, utbyggnaden, 5g nätet,...
# 44  [nordkorea, usa, nordkoreas, luhansk, donetsk ...
# 45  [genomiska, nya genomiska, tekniker, genomiska...
# 46  [mali, militära, takuba, militära insatser, ma...
# 47  [antibiotika, antibiotikaresistens, djur, eu, ...
# 48  [hagia, hagia sofia, sofia, turkiet, klostret,...
# 49  [domstolarna, försvarare, advokater, offentlig...
# 50  [hedersrelaterat, hedersrelaterat våld, våld f...
# 51  [testning, covid 19, covid, 19, smittspårning,...
# 52  [våldsmonopol, statens våldsmonopol, åtgärdspa...
# 53  [flygplatser, flygplats, flyget, bromma, flygp...
# 54  [saudiarabien, mänskliga, rättigheter, mänskli...
# 55  [film, tv, svensk, filminstitutet, filmprodukt...
# 56  [tillväxtverket, korttidsarbete, företag, stöd...
#
#                                   Representative_Docs
# 0   [Viktor Wärnyck (M) har frågat mig om jag avse...
# 1   [Svar på fråga 2020/21:1487 av Thomas Morell (...
# 2   [Meddelande om uteblivet svar på fråga 2020/21...
# 3   [Svar på fråga 2019/20:1607 av Sara Gille (SD)...
# 4   [Svar på fråga 2019/20:1962 av Björn Söder (SD...
# 5   [Svar på frågorna 2019/20:864 av Hans Rothenbe...
# 6   [Svar på fråga 2018/19:420 av Anders Österberg...
# 7   [Svar på fråga 2021/22:339 av Håkan Svenneling...
# 8   [Svar på fråga 2019/20:718 av Angelika Bengtss...
# 9   [ \nStora delar av kultursektorn är i behov av...
# 10  [Svar på fråga 2020/21:2386 av Björn Söder (SD...
# 11  [Svar på fråga 2020/21:1833 av John Weinerhall...
# 12  [Svar på fråga 2020/21:2942 av Ulrika Jörgense...
# 13  [Svar på fråga 2018/19:398 Maktväxling i Venez...
# 14  [Svar på frågorna 2019/20:1925, 2019/2020:1926...
# 15  [Svar på fråga 2020/21:537 av Dennis Dioukarev...
# 16  [Svar på frågorna 2019/20:1712 Påtvingad säker...
# 17  [ \nDen 12 juli försökte en grupp azerbajdzjan...
# 18  [Svar på frågorna 2020/21:1567 av Markus Wiech...
# 19  [Svar på fråga 2021/22:1420 av Angelica Lundbe...
# 20  [Svar på fråga 2020/21:445 Skydd av Sveriges s...
# 21  [Svar på fråga 2020/21:1613 av Åsa Coenraads (...
# 22  [Svar på fråga 2020/21:2652 av Björn Söder (SD...
# 23  [Svar på fråga 2018/19:522 av Linus Sköld (S)R...
# 24  [Svar på fråga 2019/20:1399 av Markus Wiechel ...
# 25                                             [, , ]
# 26  [Svar på fråga 2021/22:1297 av Marie-Louise Hä...
# 27  [ \nVid årsskiftet fanns det cirka 9 000 perso...
# 28  [Svar på fråga 2019/20:931 av Magdalena Schröd...
# 29  [Svar på frågorna 2020/21:550 av Mats Sander (...
# 30  [Svar på fråga 2018/19:311 av Thomas Morell (S...
# 31  [Svar på fråga 2021/22:493 av Markus Wiechel (...
# 32  [ \nUnder en lång tid har det svenska kustnära...
# 33  [Svar på fråga 2021/22:473 av Linda Lindberg  ...
# 34  [ \nUtöver den snabba negativa utvecklingen i ...
# 35  [ \nDiabetes är en av Sveriges folksjukdomar. ...
# 36  [Svar på fråga 2020/21:145 av Tobias Andersson...
# 37  [Svar på fråga 2018/19:174 av Håkan Svenneling...
# 38  [ \nMiljontals kronor visade sig ha betalats u...
# 39  [ \nSkrivelsen Vraket efter ubåten ”Som” (Ds 2...
# 40  [Svar på fråga 2021/22:841 av Eric Westroth (S...
# 41  [Svar på fråga 2019/20:815 av Robert Halef (KD...
# 42  [Svar på fråga 2021/22:1293 av Louise Meijer (...
# 43  [ \nDen 13 augusti 2018 undertecknade USA:s pr...
# 44  [Svar på fråga 2021/22:1805 av Björn Söder (SD...
# 45  [ \nFöre sommaren diskuterade EU:s ansvariga m...
# 46  [Svar på fråga 2019/20:1995 av Björn Söder (SD...
# 47  [Svar på fråga 2020/21:2472 av Sten Bergheden ...
# 48  [ \nTurkiet har i decennier förtryckt och förf...
# 49  [ClasGöran Carlsson har frågat mig om jag kan ...
# 50  [Svar på fråga 2020/21:1410 av Magdalena Schrö...
# 51  [Svar på fråga 2019/20:1298 av Camilla Walters...
# 52  [ \nUnder påskhelgen ägde fruktansvärda korank...
# 53  [Svar på fråga 2019/20:1698 av Hans Wallmark (...
# 54  [Svar på fråga 2019/20:1668 av Sara Gille (SD)...
# 55  [Svar på fråga 2019/20:624 av Pyry Niemi (S)In...
# 56  [Svar på fråga 2020/21:2004 Jämförelsemånad i ...

# %%
model_qa.visualize_heatmap(n_clusters = 20)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d2312797-82ec-4247-8cdd-d689199d1fd6" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d2312797-82ec-4247-8cdd-d689199d1fd6")) {                    Plotly.newPlot(                        "d2312797-82ec-4247-8cdd-d689199d1fd6",                        [{"coloraxis":"coloraxis","name":"0","x":["0_regeringen_fr\u00e5ga_sverige","2_besvaras_\u00f6verg\u00e5ngsregerin...","25___","27_solceller_privatpersoner...","40_folkbokf\u00f6ringen_adress_s...","46_mali_milit\u00e4ra_takuba","1_elever_skolan_l\u00e4rare","20_5g_pts_utbyggnaden","45_genomiska_nya genomiska_...","51_testning_covid 19_covid","56_tillv\u00e4xtverket_korttidsa...","3_turkiet_turkiska_turkiets","17_azerbajdzjan_armenien_na...","41_libanon_explosionen_fn","4_israel_palestinska_palest...","5_taiwan_taiwans_who","24_hongkong_hongkongs_kina","43_kinesiska_5g_huawei","6_iran_iranska_m\u00e4nskliga","7_etiopien_tigray_m\u00e4nskliga","18_myanmar_milit\u00e4ren_milit\u00e4...","28_unrwa_palestinska_fn","31_kina_os_m\u00e4nskliga","48_hagia_hagia sofia_sofia","54_saudiarabien_m\u00e4nskliga_r...","8_journalister_medier_radio","55_film_tv_svensk","9_kulturen_kultur_kultursek...","13_venezuela_kuba_m\u00e4nskliga","10_kristna_religions_religi...","14_rasism_hatbrott_antisemi...","22_folkmordet_1915_folkmord","50_hedersrelaterat_hedersre...","11_spel_spelmarknaden_sheka...","19_konsumenter_angelica lun...","23_postnord_post_brev","30_morell_thomas morell_tho...","42_pass_v\u00e4ntetiderna_v\u00e4ntet...","12_idrott_idrotten_aktivitet","21_snus_tobak_cigaretter","35_diabetes_fetma_\u00f6vervikt","15_poliser_polismyndigheten...","38_studief\u00f6rbunden_folkbild...","49_domstolarna_f\u00f6rsvarare_a...","52_v\u00e5ldsmonopol_statens v\u00e5l...","16_kina_hongkong_kinas","34_xinjiang_kina_kinesiska","26_ukraina_flyktingar_ukrai...","36_estland_nya uppgifterna_...","37_krigsmateriel_export_isp","39_ub\u00e5ten_vraket_b\u00e4rgning","29_kamerabevakning_kameror_...","32_fisket_\u00f6stersj\u00f6n_fiske","33_gravida_f\u00f6rlossningsv\u00e5rd...","44_nordkorea_usa_nordkoreas","47_antibiotika_antibiotikar...","53_flygplatser_flygplats_fl..."],"y":["0_regeringen_fr\u00e5ga_sverige","2_besvaras_\u00f6verg\u00e5ngsregerin...","25___","27_solceller_privatpersoner...","40_folkbokf\u00f6ringen_adress_s...","46_mali_milit\u00e4ra_takuba","1_elever_skolan_l\u00e4rare","20_5g_pts_utbyggnaden","45_genomiska_nya genomiska_...","51_testning_covid 19_covid","56_tillv\u00e4xtverket_korttidsa...","3_turkiet_turkiska_turkiets","17_azerbajdzjan_armenien_na...","41_libanon_explosionen_fn","4_israel_palestinska_palest...","5_taiwan_taiwans_who","24_hongkong_hongkongs_kina","43_kinesiska_5g_huawei","6_iran_iranska_m\u00e4nskliga","7_etiopien_tigray_m\u00e4nskliga","18_myanmar_milit\u00e4ren_milit\u00e4...","28_unrwa_palestinska_fn","31_kina_os_m\u00e4nskliga","48_hagia_hagia sofia_sofia","54_saudiarabien_m\u00e4nskliga_r...","8_journalister_medier_radio","55_film_tv_svensk","9_kulturen_kultur_kultursek...","13_venezuela_kuba_m\u00e4nskliga","10_kristna_religions_religi...","14_rasism_hatbrott_antisemi...","22_folkmordet_1915_folkmord","50_hedersrelaterat_hedersre...","11_spel_spelmarknaden_sheka...","19_konsumenter_angelica lun...","23_postnord_post_brev","30_morell_thomas morell_tho...","42_pass_v\u00e4ntetiderna_v\u00e4ntet...","12_idrott_idrotten_aktivitet","21_snus_tobak_cigaretter","35_diabetes_fetma_\u00f6vervikt","15_poliser_polismyndigheten...","38_studief\u00f6rbunden_folkbild...","49_domstolarna_f\u00f6rsvarare_a...","52_v\u00e5ldsmonopol_statens v\u00e5l...","16_kina_hongkong_kinas","34_xinjiang_kina_kinesiska","26_ukraina_flyktingar_ukrai...","36_estland_nya uppgifterna_...","37_krigsm ...

# %%
document_topic_qa = model_qa.get_document_info(original_qa)

document_topic_q = document_topic_qa.iloc[::2]  # Select every other row starting from the first row
document_topic_a = document_topic_qa.iloc[1::2]  # Select every other row starting from the second row

# Index needs to be resetted
document_topic_q.reset_index(drop=True, inplace=True)
document_topic_a.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### BERTopic combined
# Note: Here bertopic setting nr_topics='auto' was used to automatically let BERTopic reduce amount of topics. After consideration we decided not to use this since we got a large nonsense topic (topic 0). It was not used on the dataset with all data from 2006-2022.

# %%
# Train the BERTopic model on a text that for each datapoint questions and answers are combined into one entry.
model_combined = BERTopic(language="swedish",
                          calculate_probabilities=True,
                          vectorizer_model=vectorizer_model,
                          nr_topics = 'auto',)

topics_combined, probs_combined = model_combined.fit_transform(orginal_text_combined)

model_combined = reduce_outliers(model_combined, orginal_text_combined, topics_combined)
# Out:
# 2023-11-28 09:29:34,002 - BERTopic - WARNING: Using a custom list of topic assignments may lead to errors if topic reduction techniques are used afterwards. Make sure that manually assigning topics is the last step in the pipeline.Note that topic embeddings will also be created through weightedc-TF-IDF embeddings instead of centroid embeddings.

# %% [markdown]
# ### Save model result in data file
# The following code saves the topic ID and top 10 words for a topic for each datapoint in our dataset.

# %%
# document_topic_q
# document_topic_a
document_topic_combined = model_combined.get_document_info(orginal_text_combined)

columns_to_extract = ['Topic', 'Top_n_words']
data = data_init.copy()

for i, entry in enumerate(data):
    # combined
    id_topic, words = document_topic_combined.loc[i, columns_to_extract].values
    id_topic = id_topic.item()
    words = words.split(' - ')
    words = ', '.join(words)

    #questions
    id_topic_Q, words_Q = document_topic_q.loc[i, columns_to_extract].values
    id_topic_Q = id_topic_Q.item()
    words_Q = words_Q.split(' - ')
    words_Q = ', '.join(words_Q)

    if len(entry['answer']) == 0:
        # Answers
        id_topic_A = ''
        words_A =  []

    else:
        # Answers
        id_topic_A, words_A = document_topic_a.loc[i, columns_to_extract].values
        id_topic_A = id_topic_A.item()
        words_A = words_A.split(' - ')
        words_A = ', '.join(words_A)

    new_element = { 'id_topic_combined': id_topic, 'top_10_words_combined': words,
                    'id_topic_question': id_topic_Q, 'top_10_words_question': words_Q,
                    'id_topic_answer': id_topic_A, 'top_10_words_answer': words_A}

    entry.update(new_element)

# %%
data[0]
# Out:
# {'id_': 'h911987',
#  'question': 'av Betty Malmberg (M)\ntill Utbildningsminister Anna Ekström (S)\n\xa0\nÅr 2010 antog Europaparlamentet det så kallade djurförsöksdirektivet (2010/63/EU). Syftet med direktivet är att de försök som i dag görs på levande djur i antingen vetenskapliga eller utbildningsmässiga sammanhang ska ersättas med djurfria metoder, där det är vetenskapligt möjligt.\nNederländerna har redan antagit en strategi för detta som innebär att de fram till 2025 ska ha fasat ut många av djurförsöken samt ha antagit olika handlingsplaner för att minska djurförsök inom bland annat grundforskning. Nederländernas initiativ är mycket intressant ur flera aspekter såsom etik, effektivitet och ekonomi. Det är också högst rimligt eftersom det i dag finns alternativa sätt för att utveckla läkemedel som är mer effektiva och som dessutom kan korta processerna för framtagande av desamma. Det kan vara via studier på levande celler, i provrör eller genom beräkningsmodeller i datorn. Det innebär att fler sjuka får hjälp snabbare och till en avsevärt lägre kostnad för läkemedelsutveckling. \nI september förra året uppmanade EU-parlamentet kommissionen att utarbeta en övergripande handlingsplan för att fasa ut användningen av djur i djurförsök. Handlingsplanen ska innehålla milstolpar och mål för att snabba på att ersätta djurförsök med andra metoder som svarar bättre mot hur människor fungerar. \nModeraterna anser att satsningar på så kallad djurfri forskning är viktiga och av central betydelse. Dels för att metoden förkortar djurs lidande, dels för att den ger snabbare tillgång för människa och djur till såväl nya läkemedel som medicinsk teknik. Djurfri forskning är dessutom ett svenskt styrkeområde. Det är också skäl till att vi satsade extra resurser i vårt svar på nu gällande forskningsproposition. Vi menar att det är hög tid att Sverige agerar. Vi behöver såväl en strategi för utfasningen som mer forskning om djurförsöksfria metoder. \nMed anledning av detta vill jag fråga utbildningsminister Anna Ekström:\n\xa0\nVilka åtgärder kommer ministern att vidta för att stimulera och öka användningen av djurfria försöksmetoder där det är vetenskapligt möjligt?',
#  'question_date': '2022-02-02',
#  'answer': 'Svar på fråga 2021/22:987 av Betty Malmberg (M)Djurfria forskningsmetoder\nBetty Malmberg har frågat mig om vilka åtgärder jag kommer att vidta för att stimulera och öka användningen av djurfria försöksmetoder där det är vetenskapligt möjligt.\nSverige är ett föregångsland när det gäller djurskydd och det är regeringens ambition att Sverige ska fortsätta att vara det. När det gäller användning av försöksdjur är grundförutsättningen att djur får användas bara om syftet med försöket inte kan uppnås utan användning av djur, att så få djur som möjligt används och att djuren inte utsätts för större lidande än vad som är absolut nödvändigt, enligt den s.k. 3R-principen, från engelskans replace, reduce och refine. Jag ser det som angeläget att fler alternativa metoder till djurförsök utvecklas.\xa0\n3R-principen är väl etablerad i Sverige och vid Jordbruksverket finns ett kompetenscentrum för 3R-frågor som har byggts upp i samverkan med företrädare för forskarsamhället, industrin och djurskyddsorganisationer. Sveriges 3R-center arbetar med att bistå forskningsfinansiärer och långsiktigt verka för att större vikt ska läggas på 3R-aspekter i forskningsansökningar. 3R-centret bidrar till att stärka djurskyddet för försöksdjuren genom att främja och samordna arbetet med alternativ till djurförsök. 3R-centret har också fått i uppdrag av Sveriges nationella kommitté för skydd av djur som används för vetenskapliga ändamål att ta fram en strategi för hur djurförsöken ska kunna fasas ut på sikt. Jordbruksverket har tillförts 15 miljoner kronor per år 2021–2023 för arbete inom Jordbruksverkets kompetenscentrum för 3R-frågor i enlighet med budgetpropositionen för 2021. \nVetenskapsrådet finansierar årligen forskning om och utveckling av alternativa metoder till djurförsök. För 2022 ska 17 miljoner kronor användas för detta ändamål och utlysningar ska ske i samråd med Jordbruksverket. Finansieringen inkluderar även öronmärkta medel till svenska laboratoriers medverkan i projekt om utvärdering av alternativa metoder på EU-nivå. \nVidare avsätter forskningsrådet Formas totalt 18 miljoner kronor per år för forskning om djurskydd och djurskyddsfrämjande åtgärder. Syftet är att bidra till ökad kunskap och användning av kunskap baserad på forskning i djurskydds- och djurvälfärdsrelaterade frågor.\nGenom dessa satsningar arbetar Sverige med fortsatt utveckling av alternativa metoder till djurförsök. Detta är ett viktigt steg för att ersätta alla försök på levande djur, i vetenskapliga syften och i undervisningssyfte, så snart det är vetenskapligt möjligt att göra det.\xa0\xa0\nStockholm den 9 februari 2022\nAnna Ekström',
#  'undertecknare_name': 'Betty Malmberg',
#  'undertecknare_partibet': 'M',
#  'besvaradav_name': 'Utbildningsminister Anna Ekström',
#  'besvaradav_partibet': 'S',
#  'id_topic_combined': 36,
#  'top_10_words_combined': 'djur, veterinärer, djuret, köparen, hästen, hästar, säljaren, djuren, djursjukskötare, levande',
#  'id_topic_question': 0,
#  'top_n_words_question': 'regeringen, fråga, sverige, åtgärder, 2020, avser, 2021, kommer, vill, även',
#  'id_topic_answer': 0,
#  'top_n_words_answer': 'regeringen, fråga, sverige, åtgärder, 2020, avser, 2021, kommer, vill, även'}

# %%
import json

with open("../../data/data 2018-09-09 2022-09-11/data_topic.json", "w") as fp:
    json.dump(data, fp)  # encode dict into JSON

# %% [markdown]
# ### Improve BERTopic
# We can now try to improve BERTopic even further by playing around with all features the package provides. I followed a guide [4] that provides additional representation models which could help give better top n words for each topic.
#
# [4] M. Mansurova, Topics per Class Using BERTopic, 2023, Towards Data Science. https://towardsdatascience.com/topics-per-class-using-bertopic-252314f2640

# %%
# Here BERTopic is applied on questions and answers together. [question1, answer1, question2, answer2, etc...]
from sklearn.feature_extraction.text import CountVectorizer
from bertopic.representation import KeyBERTInspired, PartOfSpeech, MaximalMarginalRelevance

# use sv_core_news_sm for swedish
main_representation_model    = None
aspect_representation_model1 = KeyBERTInspired()
aspect_representation_model2 = PartOfSpeech("sv_core_news_sm")
aspect_representation_model3 = [KeyBERTInspired(),
                                MaximalMarginalRelevance(diversity=.5)]#diversity=.7)]

# Different representation models can be compared
representation_model = {
   "Main": main_representation_model,
   "Aspect1":  aspect_representation_model1,
   "Aspect2":  aspect_representation_model2,
   "Aspect3":  aspect_representation_model3
}

vectorizer_model = CountVectorizer(min_df=2, stop_words = stop_words, ngram_range=(1, 2))#min_df=2, ngram_range=(1, 2)

# Added swedish language and calculate_probabilities
topic_model = BERTopic(nr_topics = 'auto',
                      vectorizer_model = vectorizer_model,
                      representation_model = representation_model,
                       language="swedish",
                       calculate_probabilities=True, )

topics, ini_probs = topic_model.fit_transform(original_qa)

# %%
# check for empty entries
i = 0
for e in original_qa:
  if len(e) == 0:
    i+=1
print(i)
# Out:
# 27

# %%
topic_model.get_topic_info()
# Out:
#     Topic  Count                                               Name  \
# 0      -1   4359               -1_regeringen_fråga_åtgärder_sverige
# 1       0   7361                0_regeringen_fråga_sverige_åtgärder
# 2       1    118             1_israel_palestinska_palestina_israels
# 3       2    115                 2_turkiet_turkiska_turkiets_syrien
# 4       3    101  3_bostäder_bostadsmarknaden_hyresrätter_hyress...
# 5       4     92               4_taiwan_taiwans_who_internationella
# 6       5     69             5_etiopien_tigray_mänskliga_humanitära
# 7       6     58                    6_kina_kinesiska_kinas_hongkong
# 8       7     53    7_spel_spelmarknaden_shekarabi_spelinspektionen
# 9       8     48                   8_venezuela_kuba_chile_politiska
# 10      9     37  9_kulturarvet_kulturarv_statens_statens fastig...
# 11     10     37               10_solceller_privatpersoner_el_solel
# 12     11     35  11_azerbajdzjan_armenien_nagorno_nagorno karabach
# 13     12     32            12_5g_pts_utbyggnaden_sveriges säkerhet
# 14     13     32                13_folkmordet_1915_erkänna_folkmord
# 15     14     31              14_myanmar_militären_militärkuppen_fn
# 16     15     31  15_konsumenter_angelica lundberg_lundberg_ange...
# 17     16     31           16_postnord_post_brev_samhällsomfattande
# 18     17     31                  17_hongkong_hongkongs_kina_peking
# 19     18     27                                             18____
# 20     19     26  19_adress_folkbokföringen_skatteverket_folkbok...
# 21     20     25  20_kristna_religions_övertygelsefrihet_religio...
# 22     21     23             21_unrwa_fn_palestinska_organisationen
# 23     22     22   22_kultursektorn_kulturen_krisstöd_kulturskapare
# 24     23     20                       23_os_kina_bojkott_mänskliga
# 25     24     20       24_sporten_idrott_sport_riksidrottsförbundet
# 26     25     20  25_förlossningsvården_gravida_förlossning_bris...
# 27     26     20  26_kamerabevakning_kameror_datainspektionen_ka...
# 28     27     18                     27_libanon_explosionen_fn_stöd
# 29     28     18  28_nya uppgifterna_estland_uppgifterna_estland...
# 30     29     18  29_sammankomster_tillställningar_allmänna samm...
# 31     30     18           30_thomas morell_morell_thomas_morell sd
# 32     31     17   31_krigsmateriel_export_export krigsmateriel_isp
# 33     32     16                 32_xinjiang_kinesiska_kina_uigurer
# 34     33     16                 33_ubåten_vraket_bärgning_aspekter
# 35     34     16         34_tidsomställningen_dubbdäck_sommartid_år
# 36     35     16           35_ryssland_kärnbränsle_ryska_vattenfall
# 37     36     15                    36_journalister_hot_hot hat_hat
# 38     37     14  37_studieförbunden_folkbildningsrådet_statsbid...
# 39     38     14  38_sjuksköterskor_hälso_vfu_specialistsjuksköt...
# 40     39     14                      39_mali_militära_takuba_malis
# 41     40     14  40_domstolarna_advokater_kostnadsräkningar_bit...
# 42     41     14            41_diabetes_fetma_riktlinjerna_övervikt
# 43     42     14                          42_huawei_5g_kinesiska_ap
# 44     43     13        43_nordkorea_nordkoreas_usa_donetsk luhansk
# 45     44     12  44_våldsmonopol_statens våldsmonopol_åtgärdspa...
# 46     45     12               45_hundar_valparna_hundvalpar_valpar
# 47     46     11                     46_iranska_iran_regimen_afkari
# 48     47     11       47_oskuldsoperationer_srhr_kvinnors_flickors
# 49     48     11                48_hagia_hagia sofia_sofia_klostret
# 50     49     10         49_syrien_nordöstra syrien_nordöstra_daesh
#
#                                        Representation  \
# 0   [regeringen, fråga, åtgärder, sverige, 2020, v...
# 1   [regeringen, fråga, sverige, åtgärder, 2020, 2...
# 2   [israel, palestinska, palestina, israels, pale...
# 3   [turkiet, turkiska, turkiets, syrien, mänsklig...
# 4   [bostäder, bostadsmarknaden, hyresrätter, hyre...
# 5   [taiwan, taiwans, who, internationella, intern...
# 6   [etiopien, tigray, mänskliga, humanitära, mäns...
# 7   [kina, kinesiska, kinas, hongkong, eu, ambassa...
# 8   [spel, spelmarknaden, shekarabi, spelinspektio...
# 9   [venezuela, kuba, chile, politiska, colombia, ...
# 10  [kulturarvet, kulturarv, statens, statens fast...
# 11  [solceller, privatpersoner, el, solel, bygglov...
# 12  [azerbajdzjan, armenien, nagorno, nagorno kara...
# 13  [5g, pts, utbyggnaden, sveriges säkerhet, säke...
# 14  [folkmordet, 1915, erkänna, folkmord, erkänna ...
# 15  [myanmar, militären, militärkuppen, fn, landet...
# 16  [konsumenter, angelica lundberg, lundberg, ang...
# 17  [postnord, post, brev, samhällsomfattande, pts...
# 18  [hongkong, hongkongs, kina, peking, eu, rättig...
# 19                               [, , , , , , , , , ]
# 20  [adress, folkbokföringen, skatteverket, folkbo...
# 21  [kristna, religions, övertygelsefrihet, religi...
# 22  [unrwa, fn, palestinska, organisationen, unrwa...
# 23  [kultursektorn, kulturen, krisstöd, kulturskap...
# 24  [os, kina, bojkott, mänskliga, diplomatisk, vi...
# 25  [sporten, idrott, sport, riksidrottsförbundet,...
# 26  [förlossningsvården, gravida, förlossning, bri...
# 27  [kamerabevakning, kameror, datainspektionen, k...
# 28  [libanon, explosionen, fn, stöd, landet, eu, m...
# 29  [nya uppgifterna, estland, uppgifterna, estlan...
# 30  [sammankomster, tillställningar, allmänna samm...
# 31  [thomas morell, morell, thomas, morell sd, kon...
# 32  [krigsmateriel, export, export krigsmateriel, ...
# 33  [xinjiang, kinesiska, kina, uigurer, folkmord,...
# 34  [ubåten, vraket, bärgning, aspekter, krigsmate...
# 35  [tidsomställningen, dubbdäck, sommartid, år, l...
# 36  [ryssland, kärnbränsle, ryska, vattenfall, rys...
# 37  [journalister, hot, hot hat, hat, handlingspla...
# 38  [studieförbunden, folkbildningsrådet, statsbid...
# 39  [sjuksköterskor, hälso, vfu, specialistsjukskö...
# 40  [mali, militära, takuba, malis, minusma, insat...
# 41  [domstolarna, advokater, kostnadsräkningar, bi...
# 42  [diabetes, fetma, riktlinjerna, övervikt, obes...
# 43  [huawei, 5g, kinesiska, ap, utbyggnaden, 5g nä...
# 44  [nordkorea, nordkoreas, usa, donetsk luhansk, ...
# 45  [våldsmonopol, statens våldsmonopol, åtgärdspa...
# 46  [hundar, valparna, hundvalpar, valpar, tullver...
# 47  [iranska, iran, regimen, afkari, mohammadi, ut...
# 48  [oskuldsoperationer, srhr, kvinnors, flickors,...
# 49  [hagia, hagia sofia, sofia, klostret, mor, mos...
# 50  [syrien, nordöstra syrien, nordöstra, daesh, s...
#
#                                   Representative_Docs
# 0   [Svar på fråga 2020/21:2373, 2020/21:2374, 202...
# 1   [Svar på fråga 2020/21:2001 av Ulrika Jörgense...
# 2   [Svar på fråga 2019/20:1962 av Björn Söder (SD...
# 3   [Svar på fråga 2019/20:1703 av Markus Wiechel ...
# 4   [Svar på fråga 2019/20:461 av Momodou Malcolm ...
# 5   [Svar på frågorna 2019/20:864 av Hans Rothenbe...
# 6   [Svar på fråga 2020/21:2513 av Magnus Jacobsso...
# 7   [Svar på frågorna 2019/20:1712 Påtvingad säker...
# 8   [Svar på fråga 2020/21:1833 av John Weinerhall...
# 9   [Svar på fråga 2018/19:398 Maktväxling i Venez...
# 10  [Svar på fråga 2020/21:3257 av Per-Arne Håkans...
# 11  [Svar på fråga 2018/19:450 av Rickard Nordin (...
# 12  [ \nDen 12 juli försökte en grupp azerbajdzjan...
# 13  [Svar på fråga 2020/21:445 Skydd av Sveriges s...
# 14  [Svar på fråga 2020/21:2652 av Björn Söder (SD...
# 15  [Svar på frågorna 2020/21:1567 av Markus Wiech...
# 16  [Svar på fråga 2019/20:632 av Angelica Lundber...
# 17  [Svar på fråga 2018/19:522 av Linus Sköld (S)R...
# 18  [Svar på fråga 2018/19:862 av Åsa Coenraads (M...
# 19                                             [, , ]
# 20  [Svar på fråga 2020/21:2179 av Alireza Akhondi...
# 21  [Svar på fråga 2020/21:1464 av Sara Gille (SD)...
# 22  [Svar på fråga 2019/20:931 av Magdalena Schröd...
# 23  [Svar på fråga 2020/21:1130 av Roland Utbult (...
# 24  [Svar på fråga 2021/22:493 av Markus Wiechel (...
# 25  [Svar på fråga 2020/21:1180 av Angelika Bengts...
# 26  [Svar på fråga 2021/22:473 av Linda Lindberg  ...
# 27  [Svar på frågorna 2020/21:550 av Mats Sander (...
# 28  [Svar på fråga 2019/20:1903 av Markus Wiechel ...
# 29  [Svar på fråga 2020/21:145 av Tobias Andersson...
# 30  [Svar på frågorna 2020/21:185 av Niels Paarup-...
# 31  [Svar på fråga 2018/19:311 av Thomas Morell (S...
# 32  [Svar på fråga 2018/19:174 av Håkan Svenneling...
# 33  [ \nDet har under en längre tid varit känt i o...
# 34  [ \nSkrivelsen Vraket efter ubåten ”Som” (Ds 2...
# 35  [ \nFörra året gjordes det ett viktigt undanta...
# 36  [Svar på fråga 2020/21:2820 av Mattias Bäckstr...
# 37  [Svar på fråga 2018/19:228 av Jessica Wetterli...
# 38  [Svar på fråga 2020/21:2415, 2020/21:2416, 202...
# 39  [Svar på fråga 2020/21:3109 av Ulrika Jörgense...
# 40  [Svar på fråga 2019/20:1995 av Björn Söder (SD...
# 41  [ClasGöran Carlsson har frågat mig om jag kan ...
# 42  [ \nDiabetes är en av Sveriges folksjukdomar. ...
# 43  [ \nDen 13 augusti 2018 undertecknade USA:s pr...
# 44  [Svar på fråga 2021/22:1805 av Björn Söder (SD...
# 45  [ \nUnder påskhelgen ägde fruktansvärda korank...
# 46  [ \nMarknaden för hundfabriker och hundsmuggli...
# 47  [ \nDen iranske brottaren Navid Afkari avrätta...
# 48  [Svar på fråga 2020/21:1410 av Magdalena Schrö...
# 49  [ \nFredagen den 21 augusti beordrade den turk...
# 50  [Svar på fråga 2020/21:3184 av Anders Österber...

# %%
topic_model = reduce_outliers(topic_model, original_qa, topics)
topic_model.get_topic_info()
# Out:
# 2023-11-28 09:23:12,318 - BERTopic - WARNING: Using a custom list of topic assignments may lead to errors if topic reduction techniques are used afterwards. Make sure that manually assigning topics is the last step in the pipeline.Note that topic embeddings will also be created through weightedc-TF-IDF embeddings instead of centroid embeddings.
#     Topic  Count                                               Name  \
# 0       0  12171                0_regeringen_fråga_sverige_åtgärder
# 1       1    103               1_taiwan_taiwans_who_internationella
# 2       2     85                     2_etiopien_tigray_fn_mänskliga
# 3       3     66             3_mänskliga_venezuela_kuba_rättigheter
# 4       4     66                           4_kina_hongkong_kinas_eu
# 5       5     41                5_solceller_el_privatpersoner_solel
# 6       6     52            6_kulturarvet_statens_kulturarv_slottet
# 7       7     36                           7_postnord_post_brev_pts
# 8       8     35                8_folkmordet_1915_folkmord_osmanska
# 9       9     31               9_myanmar_militären_militärkuppen_fn
# 10     10     27                                             10____
# 11     11     36  11_folkbokföringen_skatteverket_adress_folkbok...
# 12     12     43                   12_hongkong_hongkongs_kina_kinas
# 13     13     36  13_gravida_förlossningsvården_kvinnor_förlossning
# 14     14     22  14_kamerabevakning_kameror_datainspektionen_ka...
# 15     15     34                       15_kina_os_mänskliga_bojkott
# 16     16     24                     16_unrwa_fn_palestinska_unrwas
# 17     17     22                 17_hagia_hagia sofia_turkiet_sofia
# 18     18     18                     18_libanon_explosionen_fn_stöd
# 19     19     26               19_xinjiang_kina_kinesiska_mänskliga
# 20     20     22         20_kultursektorn_kulturen_krisstöd_aktörer
# 21     21     19   21_krigsmateriel_export_export krigsmateriel_isp
# 22     22     22            22_diabetes_fetma_övervikt_riktlinjerna
# 23     23     24                          23_kinesiska_5g_huawei_ap
# 24     24     24              24_pass_väntetiderna_väntetider_tider
# 25     25     15                 25_ubåten_vraket_bärgning_aspekter
# 26     26     14                26_nordkorea_nordkoreas_usa_luhansk
# 27     27     19  27_domstolarna_försvarare_advokater_offentlig ...
# 28     28     35  28_hedersrelaterat_hedersrelaterat våld_förtry...
# 29     29     23                    29_hot_journalister_hot hat_hat
# 30     30     15  30_studieförbunden_folkbildningsrådet_folkbild...
#
#                                        Representation  \
# 0   [regeringen, fråga, sverige, åtgärder, 2020, a...
# 1   [taiwan, taiwans, who, internationella, kina, ...
# 2   [etiopien, tigray, fn, mänskliga, rättigheter,...
# 3   [mänskliga, venezuela, kuba, rättigheter, eu, ...
# 4   [kina, hongkong, kinas, eu, kinesiska, hongkon...
# 5   [solceller, el, privatpersoner, solel, förnyba...
# 6   [kulturarvet, statens, kulturarv, slottet, fas...
# 7   [postnord, post, brev, pts, samhällsomfattande...
# 8   [folkmordet, 1915, folkmord, osmanska, erkänna...
# 9   [myanmar, militären, militärkuppen, fn, eu, la...
# 10                               [, , , , , , , , , ]
# 11  [folkbokföringen, skatteverket, adress, folkbo...
# 12  [hongkong, hongkongs, kina, kinas, eu, säkerhe...
# 13  [gravida, förlossningsvården, kvinnor, förloss...
# 14  [kamerabevakning, kameror, datainspektionen, k...
# 15  [kina, os, mänskliga, bojkott, mänskliga rätti...
# 16  [unrwa, fn, palestinska, unrwas, organisatione...
# 17  [hagia, hagia sofia, turkiet, sofia, världsarv...
# 18  [libanon, explosionen, fn, stöd, landet, eu, m...
# 19  [xinjiang, kina, kinesiska, mänskliga, eu, rät...
# 20  [kultursektorn, kulturen, krisstöd, aktörer, k...
# 21  [krigsmateriel, export, export krigsmateriel, ...
# 22  [diabetes, fetma, övervikt, riktlinjerna, över...
# 23  [kinesiska, 5g, huawei, ap, kina, utbyggnaden,...
# 24  [pass, väntetiderna, väntetider, tider, polism...
# 25  [ubåten, vraket, bärgning, aspekter, krigsmate...
# 26  [nordkorea, nordkoreas, usa, luhansk, donetsk ...
# 27  [domstolarna, försvarare, advokater, offentlig...
# 28  [hedersrelaterat, hedersrelaterat våld, förtry...
# 29  [hot, journalister, hot hat, hat, våld, handli...
# 30  [studieförbunden, folkbildningsrådet, folkbild...
#
#                                               Aspect1  \
# 0   [fråga 2020, 2020 21, 2022, åtgärder, 2019 20,...
# 1   [taiwans deltagande, stödja taiwans, stöd taiw...
# 2   [etiopiska regeringen, etiopiska, humanitärt t...
# 3   [chiles regering, venezuela, chile, chiles, ku...
# 4   [säkerhetslagstiftning hongkong, situationen h...
# 5   [solenergianläggningar, solcellsanläggningar, ...
# 6   [nationalmuseum, museiverksamhet, kulturarvet,...
# 7   [samhällsomfattande posttjänsten, posttjänsten...
# 8   [folkmordet 1915, erkänna folkmordet, svenska ...
# 9   [burma, fråga utrikesminister, militärens ager...
# 10                               [, , , , , , , , , ]
# 11  [folkbokföringen skatteverket, folkbokföringsd...
# 12  [hongkongs självstyrande, situationen hongkong...
# 13  [förlossningsvården kvinnors, förlossningsvård...
# 14  [tillståndsplikten kamerabevakning, användning...
# 15  [bojkott, bojkott vinter, diplomatisk, diploma...
# 16  [stödet unrwa, stöd unrwa, bistånd unrwa, unrw...
# 17  [istanbul, turkiska myndigheter, turkiets pres...
# 18  [libanons, libanon, beiruts, libanesiska, sver...
# 19  [situationen xinjiang, xinjiang regeringen, ki...
# 20  [aktörer kultursektorn, krisstöden, krisstöd, ...
# 21  [vapenexportaffärer demokratiska, förenade ara...
# 22  [diabetes sveriges, vidta diabetesvården, diab...
# 23  [huawei, kinesiska bolag, kinesiska företaget,...
# 24  [väntetiderna pass, fråga 2021, passutfärdande...
# 25  [ryssland, ubåten, ubåtar, ryska, utifrån krig...
# 26  [nordkorea svar, nordkoreas, nordkorea, usa no...
# 27  [advokatsamfundet, sveriges domstolar, verksam...
# 28  [oskuldsoperationer sverige, svenska samhället...
# 29  [gärningar journalister, journalister förtroen...
# 30  [folkbildningsrådet studieförbunden, 2020 21, ...
#
#                                               Aspect2  \
# 0   [regeringen, fråga, åtgärder, svar, svenska, a...
# 1   [internationella, internationella organisation...
# 2   [mänskliga, humanitära, rättigheter, mänskliga...
# 3   [politiska, mänskliga, rättigheter, mänskliga ...
# 4   [kinesiska, ambassaden, agerande, mänskliga, r...
# 5   [solceller, privatpersoner, solel, bygglov, fö...
# 6   [kulturarvet, statens, kulturarv, museer, slot...
# 7   [post, brev, samhällsomfattande, tidningar, po...
# 8   [folkmordet, folkmord, riket, erkännande, arme...
# 9   [militären, militärkuppen, landet, militärens,...
# 10                               [, , , , , , , , , ]
# 11  [adress, folkbokföringen, folkbokförd, persone...
# 12  [säkerhetslagen, mänskliga, rättigheter, utrik...
# 13  [förlossningsvården, gravida, förlossning, bri...
# 14  [kamerabevakning, kameror, kameraövervakning, ...
# 15  [bojkott, mänskliga, diplomatisk, mänskliga rä...
# 16  [palestinska, organisationen, antisemitism, hu...
# 17  [världsarv, moské, folkmordet, klostret, turki...
# 18  [explosionen, stöd, landet, miljoner, libanesi...
# 19  [kinesiska, mänskliga, folkmord, uigurer, situ...
# 20  [kultursektorn, kulturen, krisstöd, finansieri...
# 21  [krigsmateriel, export, demokratiska, vapenexp...
# 22  [fetma, diabetes, övervikt, riktlinjerna, diab...
# 23  [kinesiska, utbyggnaden, företaget, utrustning...
# 24  [pass, väntetiderna, väntetider, nytt pass, ti...
# 25  [ubåten, vraket, bärgning, aspekter, krigsmate...
# 26  [ambassaden, självutnämnda, erkännande, ambass...
# 27  [domstolarna, advokater, kostnadsräkningar, bi...
# 28  [oskuldsoperationer, hedersrelaterat, förtryck...
# 29  [journalister, hot, hat, handlingsplanen, jour...
# 30  [studieförbunden, statsbidraget, folkbildninge...
#
#                                               Aspect3  \
# 0   [fråga 2020, 2020 21, 2022, åtgärder, 2019 20,...
# 1   [taiwans deltagande, stödja taiwans, stöd taiw...
# 2   [etiopiska regeringen, etiopiska, humanitärt t...
# 3   [chiles regering, venezuela, chile, chiles, ku...
# 4   [säkerhetslagstiftning hongkong, situationen h...
# 5   [solenergianläggningar, solcellsanläggningar, ...
# 6   [nationalmuseum, museiverksamhet, kulturarvet,...
# 7   [samhällsomfattande posttjänsten, posttjänsten...
# 8   [folkmordet 1915, erkänna folkmordet, svenska ...
# 9   [burma, fråga utrikesminister, militärens ager...
# 10                               [, , , , , , , , , ]
# 11  [folkbokföringen skatteverket, folkbokföringsd...
# 12  [hongkongs självstyrande, situationen hongkong...
# 13  [förlossningsvården kvinnors, förlossningsvård...
# 14  [tillståndsplikten kamerabevakning, användning...
# 15  [bojkott, bojkott vinter, diplomatisk, diploma...
# 16  [stödet unrwa, stöd unrwa, bistånd unrwa, unrw...
# 17  [istanbul, turkiska myndigheter, turkiets pres...
# 18  [libanons, libanon, beiruts, libanesiska, sver...
# 19  [situationen xinjiang, xinjiang regeringen, ki...
# 20  [aktörer kultursektorn, krisstöden, krisstöd, ...
# 21  [vapenexportaffärer demokratiska, förenade ara...
# 22  [diabetes sveriges, vidta diabetesvården, diab...
# 23  [huawei, kinesiska bolag, kinesiska företaget,...
# 24  [väntetiderna pass, fråga 2021, passutfärdande...
# 25  [ryssland, ubåten, ubåtar, ryska, utifrån krig...
# 26  [nordkorea svar, nordkoreas, nordkorea, usa no...
# 27  [advokatsamfundet, sveriges domstolar, verksam...
# 28  [oskuldsoperationer sverige, svenska samhället...
# 29  [gärningar journalister, journalister förtroen...
# 30  [folkbildningsrådet studieförbunden, 2020 21, ...
#
#                                   Representative_Docs
# 0   [Viktor Wärnyck (M) har frågat mig om jag avse...
# 1   [Svar på frågorna 2019/20:864 av Hans Rothenbe...
# 2   [Svar på fråga 2020/21:2513 av Magnus Jacobsso...
# 3   [Svar på fråga 2018/19:398 Maktväxling i Venez...
# 4   [Svar på frågorna 2019/20:1712 Påtvingad säker...
# 5   [Svar på fråga 2018/19:450 av Rickard Nordin (...
# 6   [Svar på fråga 2019/20:694 av Magnus Oscarsson...
# 7   [Svar på fråga 2018/19:522 av Linus Sköld (S)R...
# 8   [Svar på fråga 2020/21:2652 av Björn Söder (SD...
# 9   [Svar på frågorna 2020/21:1567 av Markus Wiech...
# 10                                             [, , ]
# 11  [Svar på fråga 2021/22:1039 av Lina Nordquist ...
# 12  [ \nDen nya säkerhetslagen i Hongkong som anta...
# 13  [Svar på fråga 2021/22:473 av Linda Lindberg  ...
# 14  [Svar på frågorna 2020/21:550 av Mats Sander (...
# 15  [Svar på fråga 2021/22:493 av Markus Wiechel (...
# 16  [Svar på fråga 2021/22:17 av Björn Söder (SD)\...
# 17  [Svar på fråga 2019/20:1841 av Björn Söder (SD...
# 18  [Svar på fråga 2019/20:1903 av Markus Wiechel ...
# 19  [ \nDet har under en längre tid varit känt i o...
# 20  [Svar på fråga 2020/21:3023 av Magnus Stuart (...
# 21  [Svar på fråga 2018/19:174 av Håkan Svenneling...
# 22  [ \nDiabetes är en av Sveriges folksjukdomar. ...
# 23  [ \nDen 13 augusti 2018 undertecknade USA:s pr...
# 24  [Svar på fråga 2021/22:1293 av Louise Meijer (...
# 25  [ \nSkrivelsen Vraket efter ubåten ”Som” (Ds 2...
# 26  [Svar på fråga 2021/22:1805 av Björn Söder (SD...
# 27  [ClasGöran Carlsson har frågat mig om jag kan ...
# 28  [Svar på fråga 2020/21:1410 av Magdalena Schrö...
# 29  [Svar på fråga 2018/19:228 av Jessica Wetterli...
# 30  [Svar på fråga 2020/21:2415, 2020/21:2416, 202...

# %%
# This displays some different representation models for different topics
a = 0
b = 1
print(topic_model.get_topic_info().iloc[a]['Representation'])

print(topic_model.get_topic_info().iloc[a]['Aspect1'])
print(topic_model.get_topic_info().iloc[a]['Aspect2'])
print(topic_model.get_topic_info().iloc[a]['Aspect3'])

print("\nnytt topic \n")

print(topic_model.get_topic_info().iloc[b]['Representation'])
print(topic_model.get_topic_info().iloc[b]['Aspect1'])
print(topic_model.get_topic_info().iloc[b]['Aspect2'])
print(topic_model.get_topic_info().iloc[b]['Aspect3'])
# Out:
# ['regeringen', 'fråga', 'sverige', 'åtgärder', '2020', 'avser', 'kommer', '2021', 'vill', 'även']
# ['fråga 2020', '2020 21', '2022', 'åtgärder', '2019 20', '2021', 'bland annat', '19', '2020', '2019']
# ['regeringen', 'fråga', 'åtgärder', 'svar', 'svenska', 'anledning', 'år', 'andra', 'annat', 'ministern']
# ['fråga 2020', '2020 21', '2022', 'åtgärder', '2019 20', '2021', 'bland annat', '19', '2020', '2019']
#
# nytt topic
#
# ['taiwan', 'taiwans', 'who', 'internationella', 'kina', 'internationella organisationer', 'linde', 'ann linde', 'deltagande', 'taiwans deltagande']
# ['taiwans deltagande', 'stödja taiwans', 'stöd taiwan', 'taiwan deltar', 'intresse taiwan', 'taiwans mottagning', 'taiwan', 'taiwans', 'taiwans möjlighet', 'fråga utrikesminister']
# ['internationella', 'internationella organisationer', 'deltagande', 'organisationer', 'svar', 'fråga', 'tidigare', 'utrikesminister', 'representation', 'tidigare svar']
# ['taiwans deltagande', 'stödja taiwans', 'stöd taiwan', 'taiwan deltar', 'intresse taiwan', 'taiwans mottagning', 'taiwan', 'taiwans', 'taiwans möjlighet', 'fråga utrikesminister']

# %%
# Heatmap can help to see if topics are similar to each other
topic_model.visualize_heatmap(n_clusters = 20)

# %%
# If a representation model other than none were to be choosen. This would be probably be the one.
from bertopic.representation import MaximalMarginalRelevance

representation_model = MaximalMarginalRelevance(diversity=0.4)
topic_model = BERTopic(representation_model=representation_model)

# Reduces outlier topics. These are often marked as the topic nr -1
def reduce_outliers_representation(model, text, topics):
  # Reduce outliers
  new_topics = model.reduce_outliers(text, topics)
  # Update Topic Representation
  model.update_topics(text, topics=new_topics, vectorizer_model=vectorizer_model)
  return model

# %% [markdown]
# Above different representation models and vectorizer models are combared. I evaluated different models by looking at the topics and the words that represented them. It was a difficult choice, however, I found that the when it comes to representation model the none one worked well. For vectorizer the below settings gave good result. It omitts words that occure less than two times, handles stop words and allows for words that often occure together.
#
#
#
# ```
# vectorizer_model = CountVectorizer(min_df=2, stop_words = stop_words, ngram_range=(1, 2))
# ```

# %% [markdown]
# ## BERTopic on all data
#
# From 2006 to 2022
#
# We will take topics for:
# - Combined questions and answers
# - Question and answers as seperate entities but fitted and transformed with BERTopic at same time.
#
# The models that is created here can be find in the models folder:
# - For the model for the combined question and answer: `models/BERTopic_alldata_model_combined`.
# - For the model for the question and answer seperate but fitted and transformed together: `models/BERTopic_alldata_model_qa`.
#
# In the models folder each model also have a file for their topics and probabilities. I also tried to reduce the nr of topics, however, this creates one big topic (topic 0) that contain a big chunk of entries and its words are nonsense. Therefore, we decided to stick with the initial nr of topics that BERTopic decides.

# %%
# TODO: change path
f = open('../../data/data_all/data_all_final.json')
data_all = json.load(f)

# %%
len(data_all)
# Out:
# 18997

# %%
# Check if there are any empty questions and answers. Don't use empty questions
eq = []
ea = []
data_clean = []
for entry in data_all:
  if len(entry['question']) == 0 and len(entry['answer']) == 0:
    print(entry)
  else:
    data_clean.append(entry)
  if len(entry['question']) == 0:
    eq.append(entry['question'])
  if len(entry['answer']) == 0:
    ea.append(entry['answer'])

print(len(eq))
print(len(ea))
# Out:
# {'id_': 'h411987', 'question': '', 'question_date': '2017-03-03', 'answer': '', 'undertecknare_name': 'Maria Malmer Stenergard', 'undertecknare_partibet': 'M', 'besvaradav_name': 'Finansminister Magdalena Andersson', 'besvaradav_partibet': 'S', 'regering': 49}
# {'id_': 'h411987', 'question': '', 'question_date': '2017-03-03', 'answer': '', 'undertecknare_name': 'Maria Malmer Stenergard', 'undertecknare_partibet': 'M', 'besvaradav_name': 'Finansminister Magdalena Andersson', 'besvaradav_partibet': 'S', 'regering': 49}
# {'id_': 'h211450', 'question': '', 'question_date': '2015-04-21', 'answer': '', 'undertecknare_name': 'Roger Haddad', 'undertecknare_partibet': 'FP', 'besvaradav_name': 'Helene Hellmark Knutsson', 'besvaradav_partibet': 'S', 'regering': 49}
# 3
# 137

# %%
# Generate lists of the different data needed
all_text_combined = []
all_questions = []
all_answers = []
all_qa = []

for entry in data_clean:
    question = entry['question']
    answer = entry['answer']

    # remove the to/from formality from question. NOTE: this can't be done on all data since format is different over time.
    #question2 = remove_names(question)

    all_questions.append(question)
    all_qa.append(question)

    # Answers
    all_answers.append(answer)
    all_qa.append(answer)

    # Combined questions and answers
    all_text_combined.append(question+answer)

# %% [markdown]
# ### A try to reduce number of topics
#
# **Note:** This is just a try to reduce the topics with BERTopic's setting ```nr_topics = 'auto'```. As mentioned eariler, we decidd to not use this since it created a big nonsense topic that only contained words such as "goverment", "question", "sweden" etc. and did not provide good information. This can be seen in the following code for the topic 0.

# %%
# Train the BERTopic model on a text that for each datapoint questions and answers are combined into one entry.
model_combined = BERTopic(language="swedish",
                          calculate_probabilities=True,
                          vectorizer_model=vectorizer_model,
                          nr_topics = 'auto')

topics_combined, probs_combined = model_combined.fit_transform(all_text_combined)

model_combined = reduce_outliers(model_combined, all_text_combined, topics_combined)
# Out:
# 2023-11-30 10:43:06,494 - BERTopic - WARNING: Using a custom list of topic assignments may lead to errors if topic reduction techniques are used afterwards. Make sure that manually assigning topics is the last step in the pipeline.Note that topic embeddings will also be created through weightedc-TF-IDF embeddings instead of centroid embeddings.

# %%
model_combined.get_topic_info()
# Out:
#     Topic  Count                                               Name  \
# 0       0  16178                0_regeringen_fråga_sverige_åtgärder
# 1       1    185             1_flygplatser_flygplats_arlanda_bromma
# 2       2    165                2_israel_palestinska_gaza_palestina
# 3       3    143  3_alkohol_gårdsförsäljning_systembolaget_syste...
# 4       4    175  4_kultur_lena adelsohn_adelsohn liljeroth_lilj...
# 5       5    186                5_kina_mänskliga_kinesiska_hongkong
# 6       6    104       6_msb_räddningstjänsten_fyrverkerier_bränder
# 7       7     94                      7_telefoni_telia_pts_tillgång
# 8       8    118                   8_hälso_vård_cancervården_vården
# 9       9     79  9_idrotten_idrottsrörelsen_idrott_idrottsevene...
# 10     10     72            10_tunga_fordon_vinterdäck_tunga fordon
# 11     11     56  11_spel_spelmarknaden_shekarabi_ardalan shekarabi
# 12     12     36                   12_snus_tobak_rökning_cigaretter
# 13     13     46                         13_taiwan_taiwans_who_kina
# 14     14     40   14_besöksnäringen_turismen_turism_turistnäringen
# 15     15     40              15_solceller_el_förnybar_elproduktion
# 16     16     48             16_kärnvapen_klustervapen_vapen_indien
# 17     17     95                  17_syrien_syriska_irak_humanitära
# 18     18     45            18_flygskatt_flyget_edward_edward riedl
# 19     19     41  19_arbetsmiljöverket_dödsolyckor_arbetsplatsol...
# 20     20     32   20_tandhygienister_tandläkare_tandvård_tandhälsa
# 21     21     35  21_drönare_kameraövervakning_kamerabevakning_d...
# 22     22     54  22_saudiarabien_mänskliga_rättigheter_mänsklig...
# 23     23     68  23_kriminella_brottsförebyggande_skjutningar_k...
# 24     24     29                     24_skjutfält_me_me m2016_m2016
# 25     25     26                           25_hiv_aids_hiv aids_msm
# 26     26     24                     26_agenda 2030_agenda_2030_sfö
# 27     27     55                        27_sj_ab_vattenfall_bolaget
# 28     28     23   28_organ_organdonation_transplantation_donatorer
# 29     29     23                  29_kuba_kubanska_mänskliga_dialog
# 30     30     36     30_kyrkan_religiösa_trossamfund_svenska kyrkan
# 31     31     22  31_resor_kandidaturen_fn säkerhetsråd_säkerhet...
# 32     32     22                    32_epa_ceta_förhandlingarna_avs
# 33     33     27       33_kultur_kulturen_kultursektorn_kulturlivet
# 34     34     23               34_snus_tobak_tobaksvaror_cigaretter
# 35     35     24                     35_kosovo_romer_vitboken_romsk
# 36     36     26   36_isp_krigsmateriel_export_export krigsmateriel
# 37     37     24      37_upphovsrätten_kreativa_piratkopiering_film
# 38     38     38             38_marocko_västsahara_västsahariska_eu
# 39     39     45            39_etiopien_tigray_etiopiska_konflikten
# 40     40     27           40_somaliland_somalia_hargeisa_somaliska
# 41     41     19                   41_fetma_diabetes_övervikt_hälsa
# 42     42     18                       42_böcker_moms_ljudböcker_eu
# 43     43     20        43_aktivitet_fysisk aktivitet_fysisk_idrott
# 44     44     18        44_tortyr_wallenberg_raoul_raoul wallenberg
# 45     45     19  45_samhall_funktionsnedsättning_samhalls_arbet...
# 46     46     18                 46_unrwa_palestinska_fn_flyktingar
# 47     47     15            47_arktis_arktiska_arktiska rådet_rådet
# 48     48     23        48_skyddsrum_msb_beredskap_civila försvaret
# 49     49     15                     49_teckenspråk_döva_språk_text
# 50     50     33     50_assistans_personlig assistans_personlig_lss
# 51     51     16  51_studentbostäder_studenter_bostäder_korridor...
# 52     52     15        52_nedre_bekämpning_dalälven_nedre dalälven
# 53     53     12         53_hemlöshet_hemlösa_barn_bostadsmarknaden
# 54     54     13  54_estetiska_behandlingar_ingrepp_injektionsbe...
# 55     55     15    55_telefonförsäljning_avtal_konsumenter_telefon
# 56     56     12             56_myanmar_rakhine_rohingya_bangladesh
# 57     57     49  57_vapen_polismyndigheten_vapentillstånd_sport...
# 58     58     23                58_srhr_nicaragua_abort_rättigheter
# 59     59     12  59_parkeringstillstånd_parkering_rörelsehindra...
#
#                                        Representation  \
# 0   [regeringen, fråga, sverige, åtgärder, avser, ...
# 1   [flygplatser, flygplats, arlanda, bromma, flyg...
# 2   [israel, palestinska, gaza, palestina, israels...
# 3   [alkohol, gårdsförsäljning, systembolaget, sys...
# 4   [kultur, lena adelsohn, adelsohn liljeroth, li...
# 5   [kina, mänskliga, kinesiska, hongkong, kinas, ...
# 6   [msb, räddningstjänsten, fyrverkerier, bränder...
# 7   [telefoni, telia, pts, tillgång, bredband, pos...
# 8   [hälso, vård, cancervården, vården, behandling...
# 9   [idrotten, idrottsrörelsen, idrott, idrottseve...
# 10  [tunga, fordon, vinterdäck, tunga fordon, vint...
# 11  [spel, spelmarknaden, shekarabi, ardalan sheka...
# 12  [snus, tobak, rökning, cigaretter, röka, snuse...
# 13  [taiwan, taiwans, who, kina, deltagande, inter...
# 14  [besöksnäringen, turismen, turism, turistnärin...
# 15  [solceller, el, förnybar, elproduktion, skatte...
# 16  [kärnvapen, klustervapen, vapen, indien, konve...
# 17  [syrien, syriska, irak, humanitära, fn, sverig...
# 18  [flygskatt, flyget, edward, edward riedl, ried...
# 19  [arbetsmiljöverket, dödsolyckor, arbetsplatsol...
# 20  [tandhygienister, tandläkare, tandvård, tandhä...
# 21  [drönare, kameraövervakning, kamerabevakning, ...
# 22  [saudiarabien, mänskliga, rättigheter, mänskli...
# 23  [kriminella, brottsförebyggande, skjutningar, ...
# 24  [skjutfält, me, me m2016, m2016, försvarsmakte...
# 25  [hiv, aids, hiv aids, msm, sjukdomar, hivinfek...
# 26  [agenda 2030, agenda, 2030, sfö, dnr fi2017, f...
# 27  [sj, ab, vattenfall, bolaget, sas, sj ab, metr...
# 28  [organ, organdonation, transplantation, donato...
# 29  [kuba, kubanska, mänskliga, dialog, rättighete...
# 30  [kyrkan, religiösa, trossamfund, svenska kyrka...
# 31  [resor, kandidaturen, fn säkerhetsråd, säkerhe...
# 32  [epa, ceta, förhandlingarna, avs, eu, avtalet,...
# 33  [kultur, kulturen, kultursektorn, kulturlivet,...
# 34  [snus, tobak, tobaksvaror, cigaretter, marknad...
# 35  [kosovo, romer, vitboken, romsk, romsk inklude...
# 36  [isp, krigsmateriel, export, export krigsmater...
# 37  [upphovsrätten, kreativa, piratkopiering, film...
# 38  [marocko, västsahara, västsahariska, eu, västs...
# 39  [etiopien, tigray, etiopiska, konflikten, huma...
# 40  [somaliland, somalia, hargeisa, somaliska, val...
# 41  [fetma, diabetes, övervikt, hälsa, övervikt fe...
# 42  [böcker, moms, ljudböcker, eu, lågmoms, digita...
# 43  [aktivitet, fysisk aktivitet, fysisk, idrott, ...
# 44  [tortyr, wallenberg, raoul, raoul wallenberg, ...
# 45  [samhall, funktionsnedsättning, samhalls, arbe...
# 46  [unrwa, palestinska, fn, flyktingar, unrwas, f...
# 47  [arktis, arktiska, arktiska rådet, rådet, arkt...
# 48  [skyddsrum, msb, beredskap, civila försvaret, ...
# 49  [teckenspråk, döva, språk, text, moderna språk...
# 50  [assistans, personlig assistans, personlig, ls...
# 51  [studentbostäder, studenter, bostäder, korrido...
# 52  [nedre, bekämpning, dalälven, nedre dalälven, ...
# 53  [hemlöshet, hemlösa, barn, bostadsmarknaden, v...
# 54  [estetiska, behandlingar, ingrepp, injektionsb...
# 55  [telefonförsäljning, avtal, konsumenter, telef...
# 56  [myanmar, rakhine, rohingya, bangladesh, myanm...
# 57  [vapen, polismyndigheten, vapentillstånd, spor...
# 58  [srhr, nicaragua, abort, rättigheter, kvinnors...
# 59  [parkeringstillstånd, parkering, rörelsehindra...
#
#                                   Representative_Docs
# 0   [av Elisabeth Svantesson (M)\ntill Justitie- o...
# 1   [av Hans Wallmark (M)\ntill Infrastrukturminis...
# 2   [av Håkan Svenneling (V)\ntill Utrikesminister...
# 3   [av Boriana Åberg (M)\ntill Näringsminister Ib...
# 4   [\nden 9 mars\nFråga \n2006/07:839 Besöken på ...
# 5   [av Hans Wallmark (M)\ntill Utrikesminister An...
# 6   [av Johan Hultberg (M)\ntill Socialminister Le...
# 7   [\nden 23 november\nFråga \n2007/08:333 Telefo...
# 8   [av Camilla Waltersson Grönvall (M)\ntill Soci...
# 9   [\nden \r\n23 november\nFråga \n2011/12:171 \r...
# 10  [av Sten Bergheden (M)\ntill Statsrådet Anna J...
# 11  [av Jonas Andersson i Linghem (SD)\ntill Stats...
# 12  [av John Weinerhall (M)\ntill Socialminister L...
# 13  [av Björn Söder (SD)\ntill Utrikesminister Ann...
# 14  [\nden \r\n4 augusti\nFråga \n2009/10:971 \r\n...
# 15  [av Mikael Dahlqvist (S)\ntill Statsrådet Ibra...
# 16  [\nden \r\n15 mars\nFråga \n2012/13:402 \r\nKä...
# 17  [av Roger Haddad (FP)\ntill Statsrådet Hillevi...
# 18  [av Edward Riedl (M)\ntill Infrastrukturminist...
# 19  [\nden 21 juli\nFråga \n2007/08:1496 Dödsolyck...
# 20  [av Maria Malmer Stenergard (M)\ntill Statsråd...
# 21  [av Ewa Thalén Finné (M)\ntill Justitie- och m...
# 22  [\nden 24 januari\nFråga \n2007/08:643 Kvinnor...
# 23  [av Björn Söder (SD)\ntill Justitie- och migra...
# 24  [av Mats Green (M)\ntill Försvarsminister Pete...
# 25  [\nden \r\n24 november\nFråga \n2010/11:107 \r...
# 26  [av Sofia Arkelsten (M)\ntill Försvarsminister...
# 27  [av Lars Beckman (M)\ntill Näringsminister Ibr...
# 28  [\nden 12 december\nFråga \n2008/09:400 Åtgärd...
# 29  [av Sofia Damm (KD)\ntill Utrikesminister Marg...
# 30  [\nden 23 februari\nFråga \n2006/07:723 Begrav...
# 31  [av Sofia Arkelsten (M)\ntill Statsrådet Gabri...
# 32  [\nden \r\n13 oktober\nFråga \n2010/11:4 \r\nE...
# 33  [av Lotta Finstorp (M)\ntill Kultur- och demok...
# 34  [av Sofia Fölster (M)\ntill Socialminister Ann...
# 35  [av Tina Acketoft (L)\ntill Kultur- och demokr...
# 36  [av Boriana Åberg (M)\ntill Justitie- och migr...
# 37  [av Jörgen Warborn (M)\ntill Kultur- och demok...
# 38  [\nden 11 december\nFråga \n2007/08:458 Fiskea...
# 39  [av Anders Österberg (S)\ntill Statsrådet Per ...
# 40  [av Birgitta Ohlsson (FP)\ntill Utrikesministe...
# 41  [av Camilla Waltersson Grönvall (M)\ntill Soci...
# 42  [\nden \r\n5 december\nFråga \n2013/14:166 \r\...
# 43  [\nden 15 februari\nFråga \n2007/08:775 Regelb...
# 44  [\nden 7 \r\ndecember\nFråga \r\n\n2006/07:302...
# 45  [av Saila Quicklund (M)\ntill Arbetsmarknadsmi...
# 46  [av Björn Söder (SD)\ntill Statsrådet Matilda ...
# 47  [av Sofia Arkelsten (M)\ntill Utrikesminister ...
# 48  [\nden \r\n29 november\nFråga \n2012/13:168 \r...
# 49  [\nden \r\n28 mars\nFråga \n2011/12:494 \r\nTe...
# 50  [av Ann-Charlotte Hammar Johnsson (M)\ntill St...
# 51  [av Mikael Eskilandersson (SD)\ntill Statsråde...
# 52  [av Solveig Zander (C)\ntill Miljöminister Kar...
# 53  [av Sara Gille (SD)\ntill Socialminister Lena ...
# 54  [av Cecilia Widegren (M)\ntill Statsrådet Gabr...
# 55  [\nden 29 mars\nFråga \n2006/07:960 Konsuments...
# 56  [av Jamal Mouneimne (S)\ntill Utrikesminister ...
# 57  [av Eric Palmqvist (SD)\ntill Statsrådet Mikae...
# 58  [\nden 21 december\nFråga \n2007/08:535 Yttran...
# 59  [av Betty Malmberg (M)\ntill Statsrådet Tomas ...

# %%
model_qa = BERTopic(language="swedish",
                    calculate_probabilities=True,
                    vectorizer_model=vectorizer_model,
                    nr_topics = 'auto')

topics_qa, probs_qa = model_qa.fit_transform(all_qa)
model_qa = reduce_outliers(model_qa, all_qa, topics_qa)

model_qa.get_topic_info()
# Out:
# 2023-11-30 11:00:31,559 - BERTopic - WARNING: Using a custom list of topic assignments may lead to errors if topic reduction techniques are used afterwards. Make sure that manually assigning topics is the last step in the pipeline.Note that topic embeddings will also be created through weightedc-TF-IDF embeddings instead of centroid embeddings.
#     Topic  Count                                               Name  \
# 0       0  33673                0_regeringen_fråga_sverige_åtgärder
# 1       1    272  1_alkohol_gårdsförsäljning_systembolaget_syste...
# 2       2    134                                              2____
# 3       3    141                          3_taiwan_taiwans_who_kina
# 4       4    162               4_msb_bränder_fyrverkerier_beredskap
# ..    ...    ...                                                ...
# 90     90     13    90_honduras_situationen honduras_cáceres_mexiko
# 91     91     22           91_flygplatser_flyget_fråga 2019_2019 20
# 92     92     14        92_kryptovalutor_bitcoin_per bolund_valutor
# 93     93     33  93_kriminalvården_östersund_kriminalvårdens_fä...
# 94     94     21  94_sociala_sociala företag_företagandet_social...
#
#                                        Representation  \
# 0   [regeringen, fråga, sverige, åtgärder, avser, ...
# 1   [alkohol, gårdsförsäljning, systembolaget, sys...
# 2                                [, , , , , , , , , ]
# 3   [taiwan, taiwans, who, kina, ann linde, linde,...
# 4   [msb, bränder, fyrverkerier, beredskap, brands...
# ..                                                ...
# 90  [honduras, situationen honduras, cáceres, mexi...
# 91  [flygplatser, flyget, fråga 2019, 2019 20, 201...
# 92  [kryptovalutor, bitcoin, per bolund, valutor, ...
# 93  [kriminalvården, östersund, kriminalvårdens, f...
# 94  [sociala, sociala företag, företagandet, socia...
#
#                                   Representative_Docs
# 0   [\n\n\nDnr A2015/02886/A\n\n\n\nArbetsmarknads...
# 1   [Svar på fråga 2019/20:1093 och 2019/20:1094 a...
# 2                                              [, , ]
# 3   [Svar på fråga 2019/20:1605 av Sara Gille (SD)...
# 4   [Svar på fråga 2021/22: 440 av Johan Hultberg ...
# ..                                                ...
# 90  [\n\n\n\n\n\nUtrikesdepartementet\n\nUtrikesmi...
# 91  [Svar på fråga 2019/20:1698 av Hans Wallmark (...
# 92  [av Mikael Eskilandersson (SD)\ntill Statsråde...
# 93  [\nden 4 september\nSvar på fråga\n2008/09:117...
# 94  [\nden 22 oktober\nFråga \n2007/08:132 Främjan...
#
# [95 rows x 5 columns]

# %% [markdown]
# We can also reduce topics afterhand by specifying a number

# %%
model_combined2 = BERTopic.load("/content/gdrive/MyDrive/IT5/Data/model_all_comb")
model_qa2 = BERTopic.load("/content/gdrive/MyDrive/IT5/Data/model_all_qa")

# %%
model_combined2.get_topic_info()
model_qa2.get_topic_info()
model_combined2.get_topic_info()
# Out:
#     Topic  Count                                               Name  \
# 0       0   3502              0_regeringen_fråga_sverige_statsrådet
# 1       1   1195  1_finansminister_borg_anders borg_finansminist...
# 2       2   1143           2_brott_polisen_polismyndigheten_poliser
# 3       3    910                     3_hälso_vård_vården_regeringen
# 4       4    901                  4_elever_utbildning_skolan_lärare
# ..    ...    ...                                                ...
# 65     65     15            65_arktis_arktiska_arktiska rådet_rådet
# 66     66     14      66_telefonförsäljning_avtal_telefon_ångerrätt
# 67     67     14                  67_julen_uppmaningar_semester_jul
# 68     68     13         68_hemlöshet_hemlösa_barn_bostadsmarknaden
# 69     69     12          69_fetma_övervikt_diabetes_övervikt fetma
#
#                                        Representation  \
# 0   [regeringen, fråga, sverige, statsrådet, åtgär...
# 1   [finansminister, borg, anders borg, finansmini...
# 2   [brott, polisen, polismyndigheten, poliser, mo...
# 3   [hälso, vård, vården, regeringen, sjukvården, ...
# 4   [elever, utbildning, skolan, lärare, utbildnin...
# ..                                                ...
# 65  [arktis, arktiska, arktiska rådet, rådet, arkt...
# 66  [telefonförsäljning, avtal, telefon, ångerrätt...
# 67  [julen, uppmaningar, semester, jul, smittsprid...
# 68  [hemlöshet, hemlösa, barn, bostadsmarknaden, m...
# 69  [fetma, övervikt, diabetes, övervikt fetma, fy...
#
#                                   Representative_Docs
# 0   [av Marléne Lund Kopparklint (M)\ntill Närings...
# 1   [\nden \r\n19 januari\nFråga \n2010/11:228 \r\...
# 2   [av Boriana Åberg (M)\ntill Justitie- och migr...
# 3   [av Jenny Petersson (M)\ntill Socialminister A...
# 4   [av Michael Rubbestad (SD)\ntill Utbildningsmi...
# ..                                                ...
# 65  [av Sofia Arkelsten (M)\ntill Utrikesminister ...
# 66  [\nden 29 mars\nFråga \n2006/07:960 Konsuments...
# 67  [av Björn Söder (SD)\ntill Försvarsminister Pe...
# 68  [av Sara Gille (SD)\ntill Socialminister Lena ...
# 69  [av Camilla Waltersson Grönvall (M)\ntill Soci...
#
# [70 rows x 5 columns]

# %% [markdown]
# ### Actual implementation (no reduced topics)

# %%
# Train the BERTopic model on a text that for each datapoint questions and answers are combined into one entry.
model_combined2 = BERTopic(language="swedish",
                          calculate_probabilities=True,
                          vectorizer_model=vectorizer_model)

topics_combined2, probs_combined2 = model_combined2.fit_transform(all_text_combined)

model_combined2 = reduce_outliers(model_combined2, all_text_combined, topics_combined2)
model_combined2.get_topic_info()
# Out:
# 2023-11-30 12:13:59,736 - BERTopic - WARNING: Using a custom list of topic assignments may lead to errors if topic reduction techniques are used afterwards. Make sure that manually assigning topics is the last step in the pipeline.Note that topic embeddings will also be created through weightedc-TF-IDF embeddings instead of centroid embeddings.
#      Topic  Count                                               Name  \
# 0        0    638            0_trafikverket_sj_eneroth_tomas eneroth
# 1        1    685     1_finansminister_skatteverket_borg_anders borg
# 2        2    505  2_migrationsverket_asylsökande_uppehållstillst...
# 3        3    439                     3_hälso_vården_vård_sjukvården
# 4        4    370   4_bankerna_finansiella_banker_finansinspektionen
# ..     ...    ...                                                ...
# 281    281     12            281_ofredanden_sexuella_övergrepp_åberg
# 282    282     18        282_mali_hultqvist_peter hultqvist_insatsen
# 283    283     12         283_fetma_övervikt_diabetes_övervikt fetma
# 284    284     13  284_transportbidraget_transportbidrag_vilt_för...
# 285    285     16  285_trafiksäkerheten_trafiken_vägverket_synska...
#
#                                         Representation  \
# 0    [trafikverket, sj, eneroth, tomas eneroth, tom...
# 1    [finansminister, skatteverket, borg, anders bo...
# 2    [migrationsverket, asylsökande, uppehållstills...
# 3    [hälso, vården, vård, sjukvården, hälso sjukvå...
# 4    [bankerna, finansiella, banker, finansinspekti...
# ..                                                 ...
# 281  [ofredanden, sexuella, övergrepp, åberg, festi...
# 282  [mali, hultqvist, peter hultqvist, insatsen, f...
# 283  [fetma, övervikt, diabetes, övervikt fetma, fy...
# 284  [transportbidraget, transportbidrag, vilt, för...
# 285  [trafiksäkerheten, trafiken, vägverket, synska...
#
#                                    Representative_Docs
# 0    [av Roland Utbult (KD)\ntill Statsrådet Tomas ...
# 1    [\nden \r\n22 juni\nFråga \n2010/11:615 \r\nÅt...
# 2    [av Mikael Cederbratt (M)\ntill Justitie- och ...
# 3    [av Camilla Waltersson Grönvall (M)\ntill Soci...
# 4    [\nden \r\n10 februari\nFråga \n2013/14:408 \r...
# ..                                                 ...
# 281  [av Boriana Åberg (M)\ntill Statsrådet Anders ...
# 282  [av Hans Wallmark (M)\ntill Statsrådet Matilda...
# 283  [av Camilla Waltersson Grönvall (M)\ntill Soci...
# 284  [av Eric Palmqvist (SD)\ntill Näringsminister ...
# 285  [\nden 19 januari\nFråga \n2006/07:505 Vita kä...
#
# [286 rows x 5 columns]

# %%
# import pickle

# model_combined2.save("models/BERTopic_alldata_model_combined", serialization="pickle")

# with open("models/BERTopic_alldata_topics_combined", "wb") as fp:
#   pickle.dump(topics_combined2, fp)

# with open("models/BERTopic_alldata_probs_combined", "wb") as fp:
#   pickle.dump(probs_combined2, fp)

# # Load model, topics and probabilities
# model_combined2 = BERTopic.load("models/BERTopic_alldata_model_combined")

# with open("models/BERTopic_alldata_topics_combined", "rb") as fp:
#   topics_combined2 = pickle.load(fp)

# with open("models/BERTopic_alldata_probs_combined", "rb") as fp:
#   probs_combined2 = pickle.load(fp)
# Out:
# 2023-11-30 12:33:57,155 - BERTopic - WARNING: When you use `pickle` to save/load a BERTopic model,please make sure that the environments in which you saveand load the model are **exactly** the same. The version of BERTopic,its dependencies, and python need to remain the same.

# %%
model_qa2 = BERTopic(language="swedish",
                    calculate_probabilities=True,
                    vectorizer_model=vectorizer_model)

topics_qa2, probs_qa2 = model_qa2.fit_transform(all_qa)
model_qa2 = reduce_outliers(model_qa2, all_qa, topics_qa2)

model_qa2.get_topic_info()
# Out:
# 2023-11-30 12:29:23,424 - BERTopic - WARNING: Using a custom list of topic assignments may lead to errors if topic reduction techniques are used afterwards. Make sure that manually assigning topics is the last step in the pipeline.Note that topic embeddings will also be created through weightedc-TF-IDF embeddings instead of centroid embeddings.
#      Topic  Count                                               Name  \
# 0        0   1974                  0_elever_skolan_lärare_utbildning
# 1        1   1325  1_migrationsverket_asylsökande_uppehållstillst...
# 2        2   1145     2_finansminister_skatteverket_anders borg_borg
# 3        3    681     3_bostäder_bostadsmarknaden_hyresrätter_bostad
# 4        4    491           4_etiopien_västsahara_somaliland_somalia
# ..     ...    ...                                                ...
# 460    460     18    460_tiggeri_beredskapspolisen_tigger_utsatta eu
# 461    461     14       461_griskött_tyskt_högnivågruppen_svensk mat
# 462    462     17  462_ersättningsnämnden_upprättelse_samira_mari...
# 463    463     23      463_järnvägar_underhåll_vägar järnvägar_vägar
# 464    464     21  464_yttrandefriheten_facebook_internet_godtyck...
#
#                                         Representation  \
# 0    [elever, skolan, lärare, utbildning, utbildnin...
# 1    [migrationsverket, asylsökande, uppehållstills...
# 2    [finansminister, skatteverket, anders borg, bo...
# 3    [bostäder, bostadsmarknaden, hyresrätter, bost...
# 4    [etiopien, västsahara, somaliland, somalia, fn...
# ..                                                 ...
# 460  [tiggeri, beredskapspolisen, tigger, utsatta e...
# 461  [griskött, tyskt, högnivågruppen, svensk mat, ...
# 462  [ersättningsnämnden, upprättelse, samira, mari...
# 463  [järnvägar, underhåll, vägar järnvägar, vägar,...
# 464  [yttrandefriheten, facebook, internet, godtyck...
#
#                                    Representative_Docs
# 0    [Svar på fråga 2021/22:1040 av Lars Hjälmered ...
# 1    [\n\n\nDnr Ju2014/6975\n\n\n\nJustitiedepartem...
# 2    [\nden 27 januari\nSvar på frågorna\n2010/11:2...
# 3    [\nden 19 augusti\nSvar på fråga\n2007/08:1520...
# 4    [av Birgitta Ohlsson (L)\ntill Statsrådet Isab...
# ..                                                 ...
# 460  [av Richard Jomshof (SD)\ntill Justitieministe...
# 461  [\nden 1 juni\nSvar på fråga\n2010/11:548 Gris...
# 462  [\nden 17 januari\nSvar på fråga\n2006/07:454 ...
# 463  [av Sten Bergheden (M)\ntill Infrastrukturmini...
# 464  [av Fredrik Lindahl (SD)\ntill Kultur- och dem...
#
# [465 rows x 5 columns]

# %%
# model_qa2.save("models/BERTopic_alldata_topics_model_qa", serialization="pickle")

# with open("models/BERTopic_alldata_topics_qa", "wb") as fp:
#   pickle.dump(topics_qa2, fp)

# with open("models/BERTopic_alldata_topics_probs_qa", "wb") as fp:
#   pickle.dump(probs_qa2, fp)

# # Load model, topics and probabilities
# model_qa2 = BERTopic.load("models/BERTopic_alldata_model_qa")

# with open("models/BERTopic_alldata_topics_qa", "rb") as fp:
#   topics_qa2 = pickle.load(fp)

# with open("models/BERTopic_alldata_probs_qa", "rb") as fp:
#   probs_qa2 = pickle.load(fp)

# %% [markdown]
# #### Save the topics with the data
#
# The top 10 words for each topic and the topic ID is saved together with the existing json dataset containing data from 2006 to 2022. This is saved to the data folder

# %%
# To save the topics in the existing dataset
document_topic_combined2 = model_combined2.get_document_info(all_text_combined)

document_topic_qa2 = model_qa2.get_document_info(all_qa)

document_topic_q2 = document_topic_qa2.iloc[::2] # To get the questions we need to take every other entry
document_topic_a2 = document_topic_qa2.iloc[1::2]

# Index needs to be resetted
document_topic_q2.reset_index(drop=True, inplace=True)
document_topic_a2.reset_index(drop=True, inplace=True)
data2 = data_clean.copy()

columns_to_extract = ['Topic', 'Top_n_words']

for i, entry in enumerate(data2):
    # combined
    id_topic, words = document_topic_combined2.loc[i, columns_to_extract].values
    id_topic = id_topic.item()
    words = words.split(' - ')
    words = ', '.join(words)

    #questions
    id_topic_Q, words_Q = document_topic_q2.loc[i, columns_to_extract].values
    id_topic_Q = id_topic_Q.item()
    words_Q = words_Q.split(' - ')
    words_Q = ', '.join(words_Q)

    # To handle empty answers. Some questions don't have answers.
    if len(entry['answer']) == 0:
        # Answers
        id_topic_A = ''
        words_A =  []

    else:
        # Answers
        id_topic_A, words_A = document_topic_a2.loc[i, columns_to_extract].values
        id_topic_A = id_topic_A.item()
        words_A = words_A.split(' - ')
        words_A = ', '.join(words_A)

    new_element = { 'id_topic_combined': id_topic, 'top_10_words_combined': words,
                    'id_topic_question': id_topic_Q, 'top_10_words_question': words_Q,
                    'id_topic_answer': id_topic_A, 'top_10_words_answer': words_A}

    entry.update(new_element)

# %%
# Save the new updated dataset that now contains topics. TODO: chnage path
with open("../../data/data_all/data_all_topic_final.json", "w") as fp:
    json.dump(data2, fp)

# %%
# Example of an entry
data2[200]
# Out:
# {'id_': 'gx11906',
#  'question': '\nden \r\n17 juni\nFråga \n2009/10:906 \r\nHandelsavtal som gynnar befolkningen\nav Ameer Sachet (s)\ntill statsrådet Ewa Björling (m)\nMineralrika utvecklingsländers befolkning borde \r\ngynnas mer av resurserna som finns. Därför borde avtalen mellan länderna och \r\nglobala gruvföretag utformas annorlunda än i dag, anser den New York-baserade \r\ntillsynsorganisationen Revenue Watch Institute. Enligt Revenue Watch Institute \r\när det i dag bolagen och ett fåtal högt uppsatta personer i länderna som ofta \r\när de stora vinnarna. Revenue Watch Institute arbetar för att befolkningen i \r\nutvecklingsländer ska få större del av vinsten från landets naturtillgångar, \r\nsom olja, gas och mineraler. De reser runt och försöker påverka regeringar och \r\nföretag. I dag är många av de avtal som gruvbolag och länder ingår med \r\nvarandra, inte något som befolkningen får insyn i. Det öppnar för korruption \r\noch landets rika mineraltillgångar gynnar inte befolkningen. Störst är problemen i Afrika där stater som Ghana och \r\nTanzania har haft enorma mineraltransporter som ser stora ut på pappret men \r\nstaterna har tjänat lite på dem. Företagen kommer från Europa, Kanada, USA, \r\nKina och Indien. \nVilka initiativ avser statsrådet att ta så att \r\nglobala gruvföretag följer en uppförandekod till förmån för den inhemska \r\nbefolkningens intressen?\n',
#  'question_date': '2010-06-17',
#  'answer': '\nden 23 juni\nSvar på fråga\n2009/10:906 Handelsavtal som gynnar befolkningen\nStatsrådet Ewa Björling\nAmeer Sachet har frågat mig vilka initiativ jag \r\navser att ta för att globala gruvföretag ska följa en uppförandekod som beaktar \r\nden inhemska befolkningens intressen.\nJag fäster stor vikt vid att svenska företag \r\nuppträder väl på alla de marknader där de är verksamma. Regeringen uppmuntrar \r\nföretag att tillämpa OECD:s riktlinjer för multinationella företag och \r\nprinciperna i FN:s Global Compact. Regeringen stöder därutöver internationella \r\ninitiativ för ökad öppenhet och transparens i företagens ekonomiska, sociala \r\noch miljömässiga rapportering, för att öka konsumentens möjligheter att \r\nkontrollera om företagen lever upp till sina åtaganden.\nDet är väl känt att i utvecklingsländer med stora \r\nnaturtillgångar så kommer intäkterna från gruvbrytning inte alltid befolkningen \r\ntill del. Många initiativ har tagits för att underlätta för sådana länder att \r\nfå kontroll på avkastningen av sina tillgångar. Ett av de mer framgångsrika är \r\nExtractive Industries Transparency Initiative (EITI), som Sverige ger \r\nfinansiellt stöd till så att det kan tillämpas i allt fler länder. Styrkan i \r\nEITI är att det är en koalition mellan regeringar, företag och civila samhället \r\noch med oberoende revision av betalningsströmmarna mellan företag och regeringar. \r\nI detta arbete deltar bland annat Revenue Watch Institute.\nAndra initiativ är Kimberleyprocessen om \r\nrådiamanter och ett pilot\xadprojekt i OECD som bygger på OECD:s riktlinjer och \r\nsyftar till att mer specifikt utveckla vägledning för utvinning av mineraler i \r\nhögriskområden.\n',
#  'undertecknare_name': 'Ameer Sachet',
#  'undertecknare_partibet': 'S',
#  'besvaradav_name': 'Ewa Björling',
#  'besvaradav_partibet': 'M',
#  'regering': 48,
#  'id_topic_combined': 194,
#  'top_10_words_combined': 'epa, ceta, förhandlingarna, avs, avtalet, avs länderna, handelsavtal, eu, avtal, länderna',
#  'id_topic_question': 148,
#  'top_10_words_question': 'ceta, epa, förhandlingarna, avs, handelsavtal, avs länderna, avtalet, länderna, avtal, frihandelsavtalet',
#  'id_topic_answer': 148,
#  'top_10_words_answer': 'ceta, epa, förhandlingarna, avs, handelsavtal, avs länderna, avtalet, länderna, avtal, frihandelsavtalet'}

# %% [markdown]
# ### Coherence score
#
# To be able to take the coherence score of a BERTopic model i followed this github issue:
# https://github.com/MaartenGr/BERTopic/issues/90

# %%
# Load model, topics and probabilities. TODO: Change path
topic_model_comb = BERTopic.load("models/BERTopic_alldata_model_combined")
topic_model_qa = BERTopic.load("models/BERTopic_alldata_model_qa")

with open("models/BERTopic_alldata_topics_combined", "rb") as fp:
  topics_comb = pickle.load(fp)

with open("models/BERTopic_alldata_topics_qa", "rb") as fp:
  topics_qa = pickle.load(fp)

# %%
import gensim.corpora as corpora
from gensim.models.coherencemodel import CoherenceModel

# Preprocess documents
cleaned_docs = topic_model_comb._preprocess_text(all_text_combined)

# Extract vectorizer and tokenizer from BERTopic
vectorizer = topic_model_comb.vectorizer_model
tokenizer = vectorizer.build_tokenizer()

# Extract features for Topic Coherence evaluation
tokens = [tokenizer(doc) for doc in cleaned_docs]
dictionary = corpora.Dictionary(tokens)
corpus = [dictionary.doc2bow(token) for token in tokens]
topic_words = [[words for words, _ in topic_model_comb.get_topic(topic)] for topic in range(len(set(topics))-1)]

# %%
# Evaluate
c_v_comb = CoherenceModel(topics=topic_words, texts=tokens, corpus=corpus,dictionary=dictionary, coherence='c_v')
coherence = c_v_comb.get_coherence()

# %%
coherence
# Out:
# 0.6899322122524747

# %%
# Evaluate
u_mass_comb = CoherenceModel(topics=topic_words,
                                 texts=tokens,
                                 corpus=corpus,
                                 dictionary=dictionary,
                                 coherence='u_mass')
coherence = u_mass_comb.get_coherence()

# %%
coherence
# Out:
# nan
